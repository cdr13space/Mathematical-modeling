# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib
import warnings
warnings.filterwarnings("ignore")

# 设置图像标签显示中文
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# 关掉pandas的warnings
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## 导入数据

# %%
Bitcoin = pd.read_csv('Data\BCHAIN-MKPRU.csv')
Gold = pd.read_csv('Data\LBMA-GOLD.csv')
Bitcoin.columns = ['Date','Value']
Gold.columns = ['Date','Value']
Bitcoin['Date'] = pd.to_datetime(Bitcoin['Date'])
Gold['Date'] = pd.to_datetime(Gold['Date'])

# %% [markdown]
# ### 交易时间

# %%
# 交易数据组合
t = pd.merge(Bitcoin[['Date','Value']],Gold[['Date','Value']],on='Date',how='left')
t.index = t['Date']
all_date = t['Date'].tolist()
# t = t.drop(columns='Date')

# 获得黄金未交易的时间
position = t.isnull().stack()[lambda x: x].index.tolist()
positions = []
for i in range(len(position)):
    positions.append(position[i][0])

# 获得完整时间的交易数据
Bitcoin_Data = t.iloc[:,[0,1]]
Bitcoin_Data.columns = ['Date', 'Value']
Gold_Data= t.iloc[:,[0,2]]
Gold_Data.columns = ['Date', 'Value']

# 将黄金未交易的时间向下填充
Gold_Data = Gold_Data.fillna(method='bfill')

# %% [markdown]
# ## 时间序列预测

# %%
# 预测结束数据
Bitcoin_Data = pd.read_csv('Bitcoin_Data.csv')
Gold_Data = pd.read_csv('Gold_Data.csv')
all_date = pd.to_datetime(Bitcoin_Data['Date']).tolist()

Bitcoin_Data.index = all_date
Gold_Data.index = all_date

# 收益率数据
#Bitcoin_Data['Volatility']= (np.log(Bitcoin_Data['Value'])-np.log(Bitcoin_Data['Value'].shift(1)))/Bitcoin_Data['Value']
#Gold_Data['Volatility']= (np.log(Gold_Data['Value'])-np.log(Gold_Data['Value'].shift(1)))/Gold_Data['Value']
Bitcoin_Data['Volatility'] = np.log(Bitcoin_Data['Value']) / np.log(
    Bitcoin_Data['Value'].shift(1))
Gold_Data['Volatility'] = np.log(Gold_Data['Value']) / np.log(
    Gold_Data['Value'].shift(1))
Bitcoin_Data.head()
# Out:
#                  Date   Value  High  Low  TR  ATR  Unit  upper_bound  \
# 2016-09-11  2016/9/11  621.65   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-12  2016/9/12  609.67   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-13  2016/9/13  610.92   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-14  2016/9/14  608.82   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-15  2016/9/15  610.38   NaN  NaN NaN  NaN   NaN          NaN
#
#             lower_bound  Value Shift     Predict  Volatility
# 2016-09-11          NaN          NaN  621.650000         NaN
# 2016-09-12          NaN       621.65  717.434097    0.996975
# 2016-09-13          NaN       609.67  706.331257    1.000319
# 2016-09-14          NaN       610.92  707.489610    0.999463
# 2016-09-15          NaN       608.82  705.543693    1.000399

# %% [markdown]
# ## 动态配比系统

# %%
start_date = all_date[0] # 起始日期
end_date = all_date[-1] # 结束日期
Vol_Data = pd.DataFrame()
print(start_date)
print(end_date)
# Out:
# 2016-09-11 00:00:00
# 2021-09-10 00:00:00

# %%
tt = 30
interval = pd.Timedelta(tt, unit='day')  # 设置间隔日期
cycle = round((end_date - start_date) / interval) - 1
change_list = []
init_date = start_date
for i in range(cycle):
    init_date += interval
    change_list.append(init_date)
print(len(change_list))
Vol_Data['Date'] = change_list

x1 = pd.Timedelta(tt, unit='day')
x2 = pd.Timedelta(1, unit='day')
x3 = pd.Timedelta(5, unit='day')

Bitcoin_profit = []
Bitcoin_mean_profit = []
Bitcoin_var = []
Gold_profit = []
Gold_mean_profit = []
Gold_var = []
corr_list = []
for i in range(len(change_list)):
    t1 = pd.date_range(change_list[i] - x1, change_list[i] - x2, freq='D')
    t2 = pd.date_range(change_list[i] + x2, change_list[i] + x3, freq='D')

    # 过去30天最大收益
    Bitcoin_max_value = Bitcoin_Data.loc[t1]['Value'].max()
    Gold_max_value = Gold_Data.loc[t1]['Value'].max()
    # 未来五天的最大收益
    Bitcoin_predict_value = Bitcoin_Data.loc[t2]['Predict'].max()
    Gold_predict_value = Gold_Data.loc[t2]['Predict'].max()
    # 预计收益率
    #Bitcoin_profit_value = (Bitcoin_predict_value -
    #                       Bitcoin_max_value) / Bitcoin_max_value
    # 预计价比率
    Bitcoin_profit_value = Bitcoin_predict_value / Bitcoin_max_value
    Bitcoin_profit.append(Bitcoin_profit_value)

    #Gold_profit_value = (Gold_predict_value - Gold_max_value) / Gold_max_value
    Gold_profit_value = Gold_predict_value / Gold_max_value
    Gold_profit.append(Gold_profit_value)

    # 过于30天收益率
    Bitcoin_vol = Bitcoin_Data.loc[t1]['Volatility']
    Gold_vol = Gold_Data.loc[t1]['Volatility']

    # 平均收益率
    Bitcoin_mean = Bitcoin_vol.mean()
    Gold_mean = Gold_vol.mean()
    Bitcoin_mean_profit.append(Bitcoin_mean)
    Gold_mean_profit.append(Gold_mean)

    # 收益率方差
    Bitcoin_var_value = Bitcoin_vol.var()
    Gold_var_value = Gold_vol.var()
    Bitcoin_var.append(Bitcoin_var_value)
    Gold_var.append(Gold_var_value)

    # 收益率协方差
    x = pd.DataFrame()
    x['Bitcoin_vol'] = Bitcoin_vol
    x['Gold_vol'] = Gold_vol
    corr_value = x.corr().iloc[0, 1]
    corr_list.append(corr_value)

Vol_Data['Bitcoin_Profit'] = Bitcoin_profit
Vol_Data['Bitcoin_Mean_Profit'] = Bitcoin_mean_profit
Vol_Data['Bitcoin_Var'] = Bitcoin_var
Vol_Data['Gold_Profit'] = Gold_profit
Vol_Data['Gold_Mean_Profit'] = Gold_mean_profit
Vol_Data['Gold_Var'] = Gold_var
Vol_Data['Corr'] = corr_list
# 保存数据
# Vol_Data.to_csv('vol_data.csv')
Vol_Data.head()
# Out:
# 60
#         Date  Bitcoin_Profit  Bitcoin_Mean_Profit  Bitcoin_Var  Gold_Profit  \
# 0 2016-10-11        1.178375             0.999965     0.000001     0.938721
# 1 2016-11-10        1.104698             1.000799     0.000010     0.970101
# 2 2016-12-10        1.116793             1.000334     0.000004     0.915641
# 3 2017-01-09        0.875224             1.000835     0.000036     1.020633
# 4 2017-02-08        1.065916             1.000718     0.000029     1.006931
#
#    Gold_Mean_Profit      Gold_Var      Corr
# 0          0.999758  8.220428e-07 -0.195307
# 1          1.000081  5.340500e-07 -0.011197
# 2          0.999549  1.493999e-06  0.232689
# 3          1.000061  1.076379e-06  0.013685
# 4          1.000206  1.683486e-06  0.273683

# %% [markdown]
# ### 动态规划

# %%
A = -1
w1, w2 = 0.5, 0.5
e = w1 * Vol_Data['Bitcoin_Profit'] + w2 * Vol_Data['Gold_Profit']
sigma = (pow(w1, 2) * Vol_Data['Bitcoin_Var'] +
         pow(w2, 2) * Vol_Data['Gold_Var']) + w1 * w2 * Vol_Data['Corr']
# 投资效用函数
Vol_Data['U'] = e - 0.5 * A * sigma

# %%
from scipy.optimize import minimize
cons = ({
    'type': 'eq',
    'fun': lambda x: -x[0] - x[1] + 1},)
bounds = ((0, 1), (0, 1))


weight = []
for i in range(Vol_Data['Bitcoin_Profit'].shape[0]):
    fun = lambda x: x[0] * Vol_Data['Bitcoin_Profit'][i] + x[1] * Vol_Data[
        'Gold_Profit'][i] - 0.5 * A * (pow(x[0], 2) * Vol_Data['Bitcoin_Var'][i] + pow(
            x[1], 2) * Vol_Data['Gold_Var'][i]) + w1 * w2 * Vol_Data['Corr'][i]
    res = minimize(fun, x0 = (0.5,0.5), bounds=bounds, method='SLSQP', constraints = cons)
    weight.append(res.x)
weight = pd.DataFrame(weight).round(2)
weight.head()
# Out:
#      0    1
# 0  0.0  1.0
# 1  0.0  1.0
# 2  0.0  1.0
# 3  1.0  0.0
# 4  0.0  1.0

# %%
Vol_Data['W0'] = weight.iloc[:,0]
Vol_Data['W1'] = weight.iloc[:,1]

# %% [markdown]
# ## 海龟交易系统
# ### 重要指标

# %%
from empyrical import value_at_risk


def get_unit(data, T=7, A=20, D1=20, D2=10, money=1000):
    """
    D1=20,D2=10 短线系统
    D1=55,D2=50 长线系统
    """
    # 起始资金
    money_init = money
    # 最近T个交易日的最高价
    data['High'] = talib.MAX(data['Value'], timeperiod=T).shift(1)
    # 最近T个交易日的最低价
    data['Low'] = talib.MIN(data['Value'], timeperiod=T).shift(1)
    # 通过以上数据近真实波动幅度 True Range
    data['TR'] = talib.TRANGE(data['High'], data['Low'], data['Value'])
    # 平均真实波幅
    data['ATR'] = talib.ATR(data['High'],
                            data['Low'],
                            data['Value'],
                            timeperiod=A)
    # 头寸规模单位
    # 交易单位为1 比特币/特洛伊盎司
    data['Unit'] = (money_init * 0.01) / (data['ATR'] * 1)
    data['upper_bound'] = data['Value'].shift(2).rolling(D1).max()
    data['lower_bound'] = data['Value'].shift(2).rolling(D2).min()
    data['Value Shift'] = data['Value'].shift(1)

    # Value at Risk
    VAR = []
    for i in range(A - 1, data.shape[0]):
        VAR.append(
            value_at_risk(data['Value'][i + 1 - A:i], cutoff=0.05))
    VAR = np.array(VAR)
    data['VAR'] = np.hstack((np.zeros(A-1), VAR))
    return data

# %%
# 预测结束数据
Bitcoin_Data =  pd.read_csv('Bitcoin_Data.csv')
Gold_Data =  pd.read_csv('Gold_Data.csv')
all_date = pd.to_datetime(Bitcoin_Data['Date']).tolist()

Bitcoin_Data.index = all_date
Gold_Data.index = all_date

# 波动率数据
Bitcoin_Data['Volatility']= (np.log(Bitcoin_Data['Value'])-np.log(Bitcoin_Data['Value'].shift(1)))/Bitcoin_Data['Value']
Gold_Data['Volatility']= (np.log(Gold_Data['Value'])-np.log(Gold_Data['Value'].shift(1)))/Gold_Data['Value']
Bitcoin_Data.head()
# Out:
#                  Date   Value  High  Low  TR  ATR  Unit  upper_bound  \
# 2016-09-11  2016/9/11  621.65   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-12  2016/9/12  609.67   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-13  2016/9/13  610.92   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-14  2016/9/14  608.82   NaN  NaN NaN  NaN   NaN          NaN
# 2016-09-15  2016/9/15  610.38   NaN  NaN NaN  NaN   NaN          NaN
#
#             lower_bound  Value Shift     Predict  Volatility
# 2016-09-11          NaN          NaN  621.650000         NaN
# 2016-09-12          NaN       621.65  717.434097   -0.000032
# 2016-09-13          NaN       609.67  706.331257    0.000003
# 2016-09-14          NaN       610.92  707.489610   -0.000006
# 2016-09-15          NaN       608.82  705.543693    0.000004

# %%
def reverse(data, f=0.0002, t=0.3):
    capital_residual = 1000.0  # 初始资本价值（美元）
    unit_position = 0  # 初始持有量
    trash = 0  # 手续费
    fees = f  # 佣金
    positions = []  # 保存交易位置
    for i in range(27, data.shape[0]):
        # 我们从28天开始循环，让ATR正确填充
        # 1. 前一天的收盘价超过高价突破位，且未进场交易;
        #    不考虑做空，进场仅买入;
        #    首次建仓为1个单位(unit)
        # 止盈条件

        if (data["Value Shift"].iloc[i] > data["upper_bound"].iloc[i]
                and unit_position == 0):
            # 使用当前价格
            price = data['Value'].iloc[i]
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * data['Unit'].iloc[i]
            unit_position += data['Unit'].iloc[i]
            # 剩余资金量
            capital_residual = capital_residual - capital_buy * (1 + fees)
            trash += capital_buy * fees
            # 总资产
            capital_all = capital_residual + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            stop_loss = price - 2.0 * data['VAR'].iloc[i]
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * data["ATR"].iloc[i]
            positions += [{
                "Date": data['Date'].iloc[i],
                "Price": price,
                "Unit": unit_position
            }]
            print("总资本", capital_all, "剩余资金: ", capital_residual, "交易位置: ",
                  price, "持有份额", unit_position, "交易时间", data['Date'].iloc[i],
                  "止损价位", stop_loss)
        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束

        if unit_position > 0 and (data["Value Shift"].iloc[i] >
                                  positions[-1]['Price']+0.5*data["ATR"].iloc[i]) and (i != data.shape[0] - 1):
            if unit_position > 4 or capital_residual <= 0:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = data['Value'].iloc[i]
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * data['Unit'].iloc[i]
                # 如果剩余资金量充足
                if (capital_buy * (1 + fees)) <= capital_residual:
                    unit_position += data['Unit'].iloc[i]
                    # 剩余资金量
                    capital_residual -= capital_buy * (1 + fees)
                    trash += capital_buy * fees
                # 若不充足
                elif (capital_buy * (1 + fees)) > capital_residual:
                    # 剩下的钱全部购买
                    unit_position += capital_residual / (price * (1 + fees))
                    trash += unit_position * price * fees
                    capital_residual = 0
                capital_all = capital_residual + unit_position * price
                positions += [{
                    "Date": data['Date'].iloc[i],
                    "Price": price,
                    "Unit": unit_position
                }]
                # stop_loss = price - (2.0 - 0.5) * data["ATR"].iloc[i]
                print("总资本", capital_all, "剩余资金: ", capital_residual, "交易位置: ",
                      price, "持有份额", unit_position, "交易时间",
                      data['Date'].iloc[i])
        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position > 0 and (
                data["Value Shift"].iloc[i] < data["lower_bound"].iloc[i]
                or data["Value Shift"].iloc[i] < stop_loss
                or i == data.shape[0] - 1):
            # 使用当前价格全部卖出
            price = data['Value'].iloc[i]
            capital_sell = unit_position * price * (1 - fees)
            trash += unit_position * price * fees
            capital_residual = capital_sell + capital_residual
            capital_all = capital_residual
            print('-' * 50)
            print('M', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position, "时间", data['Date'].iloc[i])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss, unit_position = 0.0, 0.0
    print(trash)
    return positions, capital_all,trash

# %%
Bitcoin_Data = get_unit(Bitcoin_Data.copy(), T=7, A=20, D1=20, D2=10, money=1000)
Gold_Data = get_unit(Gold_Data.copy(), T=7, A=20, D1=55, D2=50, money=1000)

# %%
# 启动回测 模拟
print("-" * 50)
print("初始资本价值: 1000美元")
print("-" * 50)
Bitcoin_Data = get_unit(Bitcoin_Data.copy(), T=7, A=20, D1=20, D2=30, money=1000)
Bitcoin_Positions, Bitcoin_Capital,trash = reverse(Bitcoin_Data, f=0.0002)
# Out:
# --------------------------------------------------
# 初始资本价值: 1000美元
# --------------------------------------------------
# 总资本 999.8951313544866 剩余资金:  475.5519037871047 交易位置:  614.74 持有份额 0.8529512111907178 交易时间 2016/10/8 止损价位 591.2919999999999
# 总资本 1017.8996646934687 剩余资金:  0 交易位置:  635.96 持有份额 1.6005718357970133 交易时间 2016/10/13
# --------------------------------------------------
# M 当前总资本 1548.5475883104555 卖出价格 967.69 卖出份额 1.6005718357970133 时间 2017/3/19
# --------------------------------------------------
# 总资本 1548.5300444545778 剩余资金:  1460.8107650662587 交易位置:  1181.149838 持有份额 0.07426600467291357 交易时间 2017/4/8 止损价位 911.84761704325
# 总资本 1552.6260301611142 剩余资金:  1339.2651417539334 交易位置:  1236.63 持有份额 0.17253413584271832 交易时间 2017/4/21
# 总资本 1561.4654332238701 剩余资金:  1203.6071245678136 交易位置:  1288.02 持有份额 0.27783598752818783 交易时间 2017/4/27
# 总资本 1573.9340418822458 剩余资金:  1061.308367296481 交易位置:  1333.0 持有份额 0.3845653972886458 交易时间 2017/4/30
# 总资本 1619.6963847950992 剩余资金:  909.892642587468 交易位置:  1452.076288 持有份额 0.48881986991556137 交易时间 2017/5/2
# 总资本 1659.3884390610283 剩余资金:  765.5964409782933 交易位置:  1533.335071 持有份额 0.5829071642506863 交易时间 2017/5/5
# 总资本 1728.0068238430827 剩余资金:  627.3886573554491 交易位置:  1651.1 持有份额 0.666596915079422 交易时间 2017/5/9
# 总资本 1841.2273848038292 剩余资金:  487.53951231898276 交易位置:  1820.990563 持有份额 0.7433799493472972 交易时间 2017/5/11
# 总资本 2013.6043965418871 剩余资金:  352.0624467925277 交易位置:  2052.909788 持有份额 0.8093594562516448 交易时间 2017/5/20
# 总资本 2178.212988310048 剩余资金:  235.10499902510702 交易位置:  2256.32 持有份额 0.8611845789980769 交易时间 2017/5/24
# 总资本 2140.0051893480577 剩余资金:  134.2447005805799 交易位置:  2211.976857 持有份额 0.9067728183593188 交易时间 2017/5/26
# 总资本 2319.4828023990594 剩余资金:  29.64213328189726 交易位置:  2409.93 持有份额 0.9501689547485455 交易时间 2017/6/2
# 总资本 2769.2713677313436 剩余资金:  0 交易位置:  2883.313697 持有份额 0.9604474777103462 交易时间 2017/6/6
# --------------------------------------------------
# M 当前总资本 2234.6007113607884 卖出价格 2327.09 卖出份额 0.9604474777103462 时间 2017/7/11
# --------------------------------------------------
# 总资本 2234.5829718516884 剩余资金:  2145.885426352356 交易位置:  2807.609857 持有份额 0.03159183434200795 交易时间 2017/7/22 止损价位 2174.5348736519827
# 总资本 2248.621265500899 剩余资金:  2052.978943699072 交易位置:  3252.562533 持有份额 0.060150210739031214 交易时间 2017/8/6
# 总资本 2254.9056199021143 剩余资金:  1966.91531339931 交易位置:  3357.326317 持有份额 0.08577965896390531 交易时间 2017/8/9
# 总资本 2297.3889750273743 剩余资金:  1874.6049050287281 交易位置:  3852.802914 持有份额 0.10973415444178784 交易时间 2017/8/12
# 总资本 2337.3388177425586 剩余资金:  1783.9606495527057 交易位置:  4217.028329 持有份额 0.13122467411099362 交易时间 2017/8/15
# 总资本 2386.916029410072 剩余资金:  1681.9237319559647 交易位置:  4594.98785 持有份额 0.15342636813590432 交易时间 2017/8/30
# 总资本 2384.6551463720366 剩余资金:  1577.896453184334 交易位置:  4580.38748 持有份额 0.1761332849481334 交易时间 2017/9/2
# --------------------------------------------------
# M 当前总资本 2162.4768504293634 卖出价格 3319.63 卖出份额 0.1761332849481334 时间 2017/9/14
# --------------------------------------------------
# 总资本 2162.460319759018 剩余资金:  2079.806968031481 交易位置:  4386.88375 持有份额 0.018841017095002095 交易时间 2017/10/2 止损价位 3325.369931549862
# 总资本 2170.590301077836 剩余资金:  1976.3828932967567 交易位置:  4819.485767 持有份额 0.040296292420004064 交易时间 2017/10/11
# 总资本 2207.6382875144395 剩余资金:  1862.8237160889 交易位置:  5739.438733 持有份额 0.060078099526171824 交易时间 2017/10/14
# 总资本 2231.46864765416 剩余资金:  1744.173010201749 交易位置:  6136.49 持有份额 0.07940950567057242 交易时间 2017/10/30
# 总资本 2280.319581771709 剩余资金:  1620.0355495162833 交易位置:  6751.98 持有份额 0.09779117122020886 交易时间 2017/11/2
# 总资本 2347.337170178904 剩余资金:  1497.7545589779152 交易位置:  7437.543317 持有份额 0.11422892949868237 交易时间 2017/11/4
# 总资本 2417.2500966773914 剩余资金:  1420.9358750268782 交易位置:  8049.72 持有份额 0.12377004686504786 交易时间 2017/11/20
# 总资本 2506.2323498919013 剩余资金:  1329.357136899175 交易位置:  8768.8 持有份额 0.13421166100181628 交易时间 2017/11/26
# 总资本 2665.0795947265096 剩余资金:  1227.9266543982685 交易位置:  9952.50882 持有份额 0.14440107176194805 交易时间 2017/11/28
# 总资本 2798.9740531287007 剩余资金:  1133.23816573042 交易位置:  10879.88 持有份额 0.15310241357425639 交易时间 2017/12/2
# 总资本 2907.8632398305226 剩余资金:  1039.798631113654 交易位置:  11591.22 持有份额 0.16116203546450406 交易时间 2017/12/5
# 总资本 3699.2658646320015 剩余资金:  919.2245389483369 交易位置:  16501.97167 持有份额 0.1684672220555124 交易时间 2017/12/7
# 总资本 4204.097359321742 剩余资金:  838.2384858655025 交易位置:  19498.68333 持有份额 0.17261980291139176 交易时间 2017/12/16
# --------------------------------------------------
# M 当前总资本 2796.2915360885745 卖出价格 11345.42333 卖出份额 0.17261980291139176 时间 2018/1/18
# --------------------------------------------------
# 总资本 2796.281037308975 剩余资金:  2743.7871393118266 交易位置:  11390.39167 持有份额 0.004608612198596021 交易时间 2018/2/20 止损价位 7050.690445823914
# --------------------------------------------------
# M 当前总资本 2783.0925913650112 卖出价格 8530.402 卖出份额 0.004608612198596021 时间 2018/3/16
# --------------------------------------------------
# 总资本 2783.0793998236113 剩余资金:  2717.1216928247336 交易位置:  7895.416926 持有份额 0.00835392324649455 交易时间 2018/4/17 止损价位 5501.332205579287
# 总资本 2790.6808277387686 剩余资金:  2639.2077526131807 交易位置:  8807.205 持有份额 0.017198767954826527 交易时间 2018/4/21
# 总资本 2805.2982133276623 剩余资金:  2553.5303320149633 交易位置:  9658.11 持有份额 0.026068027938457847 交易时间 2018/4/25
# --------------------------------------------------
# M 当前总资本 2750.7266240595422 卖出价格 7566.193333 卖出份额 0.026068027938457847 时间 2018/5/24
# --------------------------------------------------
# 总资本 2750.697530234953 剩余资金:  2605.228407289562 交易位置:  7321.62 持有份额 0.019868433891050235 交易时间 2018/7/18 止损价位 6314.998133894638
# 总资本 2758.4915658014347 剩余资金:  2486.2256066459126 交易位置:  7715.1 持有份额 0.035290010389433975 交易时间 2018/7/24
# 总资本 2775.131158863248 剩余资金:  2360.186915155606 交易位置:  8187.324167 持有份额 0.05068130139272181 交易时间 2018/7/26
# --------------------------------------------------
# M 当前总资本 2679.9793100267552 卖出价格 6311.131667 卖出份额 0.05068130139272181 时间 2018/8/12
# --------------------------------------------------
# 总资本 2679.9521720152875 剩余资金:  2544.262114677707 交易位置:  7078.19 持有份额 0.01917016318261882 交易时间 2018/8/29 止损价位 6034.902062934676
# --------------------------------------------------
# M 当前总资本 2664.253509276598 卖出价格 6260.530833 卖出份额 0.01917016318261882 时间 2018/10/12
# --------------------------------------------------
# 总资本 2664.2180087301917 剩余资金:  2486.7152766986756 交易位置:  3686.29 持有份额 0.04815213453947358 交易时间 2019/2/11 止损价位 3270.939773238928
# 总资本 2675.7473291458696 剩余资金:  2292.934597886339 交易位置:  3926.53 持有份额 0.09749390206098787 交易时间 2019/2/20
# 总资本 2660.1526144994555 剩余资金:  2138.9632027731545 交易位置:  3766.89 持有份额 0.1383606666842676 交易时间 2019/2/25
# 总资本 2675.210719149241 剩余资金:  1974.463982169947 交易位置:  3875.96 持有份额 0.18079307758059782 交易时间 2019/3/9
# 总资本 2696.676344167942 剩余资金:  1766.8250112449539 交易位置:  3994.92 持有份额 0.2327584364450322 交易时间 2019/3/18
# 总资本 2724.443188892051 剩余资金:  1504.5545686404985 交易位置:  4114.44 持有份额 0.2964895879515931 交易时间 2019/3/31
# 总资本 2975.0358820617857 剩余资金:  1250.9548743239452 交易位置:  4959.81 持有份额 0.3476102930833722 交易时间 2019/4/4
# 总资本 3082.3836662112426 剩余资金:  1105.7489189564747 交易位置:  5268.71 持有份额 0.37516484058806954 交易时间 2019/4/9
# 总资本 3144.431121005473 剩余资金:  931.5989645147713 交易位置:  5434.19 持有份额 0.40720551848402464 交易时间 2019/4/25
# 总资本 3281.575599483275 剩余资金:  736.6167544620693 交易位置:  5771.08 持有份额 0.4409848494599287 交易时间 2019/5/5
# 总资本 3535.9611391659396 剩余资金:  555.283671363214 交易位置:  6348.02 持有份额 0.469544435556713 交易时间 2019/5/11
# 总资本 3832.0277703409242 剩余资金:  391.3242288620482 交易位置:  6978.63 持有份额 0.49303424045677674 交易时间 2019/5/13
# 总资本 4331.965621452009 剩余资金:  249.04194552872033 交易位置:  7992.69 持有份额 0.5108322324428057 交易时间 2019/5/15
# 总资本 4729.050492608587 剩余资金:  145.11427672291316 交易位置:  8770.06 持有份额 0.5226801431102722 交易时间 2019/5/28
# 总资本 4889.032183252344 剩余资金:  39.31929615555198 交易位置:  9076.18 持有份额 0.5343341457636133 交易时间 2019/6/19
# 总资本 5494.531774944895 剩余资金:  0 交易位置:  10209.38 持有份额 0.5381846669381388 交易时间 2019/6/22
# --------------------------------------------------
# M 当前总资本 5153.696412615207 卖出价格 9577.99 卖出份额 0.5381846669381388 时间 2019/8/31
# --------------------------------------------------
# 总资本 5153.668227832038 剩余资金:  5012.744311985599 交易位置:  9259.8 持有份额 0.015218894127998327 交易时间 2019/10/27 止损价位 7945.64406778901
# --------------------------------------------------
# M 当前总资本 5123.612323177294 卖出价格 7286.35 卖出份额 0.015218894127998327 时间 2019/11/23
# --------------------------------------------------
# 总资本 5123.579843995795 剩余资金:  4961.183936502688 交易位置:  8165.47 持有份额 0.019888127381902942 交易时间 2020/1/8 止损价位 7159.844904386481
# 总资本 5136.4468620646085 剩余资金:  4816.947654215611 交易位置:  8813.89 持有份额 0.0362495116059989 交易时间 2020/1/16
# 总资本 5153.305660168417 剩余资金:  4664.045361575958 交易位置:  9279.81 持有份额 0.052723094394438924 交易时间 2020/1/30
# 总资本 5178.363727078769 剩余资金:  4512.927357818542 交易位置:  9755.66 持有份额 0.06821028708054891 交易时间 2020/2/7
# 总资本 5185.095813968713 剩余资金:  4364.9034171904495 交易位置:  9854.79 持有份额 0.08322779042255223 交易时间 2020/2/11
# 总资本 5226.638540868342 剩余资金:  4212.939558792598 交易位置:  10354.3 持有份额 0.09790125668328553 交易时间 2020/2/13
# --------------------------------------------------
# M 当前总资本 5074.760312906507 卖出价格 8804.72 卖出份额 0.09790125668328553 时间 2020/2/28
# --------------------------------------------------
# 总资本 5074.749272579149 剩余资金:  5019.5476357855705 交易位置:  6741.67 持有份额 0.008188125018515919 交易时间 2020/4/4 止损价位 4299.108369007101
# 总资本 5078.535013047159 剩余资金:  4956.700240920939 交易位置:  7205.55 持有份额 0.01690846252211413 交易时间 2020/4/8
# 总资本 5088.40899691114 剩余资金:  4860.047702616465 交易位置:  7790.66 持有份额 0.02931218847885477 交易时间 2020/4/28
# 总资本 5112.955040303129 剩余资金:  4756.052437603514 交易位置:  8628.77 持有份额 0.041361932546540844 交易时间 2020/5/1
# 总资本 5169.751608498451 剩余资金:  4642.368889504455 交易位置:  10002.48 持有份额 0.05272519605077893 交易时间 2020/5/8
# --------------------------------------------------
# M 当前总资本 5117.023731582353 卖出价格 9004.23 卖出份额 0.05272519605077893 时间 2020/6/28
# --------------------------------------------------
# 总资本 5116.967831071954 剩余资金:  4837.465279072677 交易位置:  9613.11 持有份额 0.02907514342385311 交易时间 2020/7/24 止损价位 8925.237210915422
# 总资本 5158.467228108089 剩余资金:  4550.334323649009 交易位置:  11042.4 持有份额 0.05507252992638196 交易时间 2020/7/28
# 总资本 5160.384239339847 剩余资金:  4395.782660809058 交易位置:  11077.77 持有份额 0.06902125414508417 交易时间 2020/8/3
# 总资本 5208.333703291515 剩余资金:  4235.544157665745 交易位置:  11772.94 持有份额 0.0826292791457164 交易时间 2020/8/7
# 总资本 5224.542494229856 剩余资金:  4059.0136140395284 交易位置:  11969.53 持有份额 0.0973746571661818 交易时间 2020/8/19
# --------------------------------------------------
# M 当前总资本 5078.116952602831 卖出价格 10467.89 卖出份额 0.0973746571661818 时间 2020/9/5
# --------------------------------------------------
# 总资本 5078.075263765292 剩余资金:  4869.631076072078 交易位置:  11376.61 持有份额 0.01832217046143044 交易时间 2020/10/12 止损价位 10285.036267395475
# 总资本 5088.086293926799 剩余资金:  4644.120501731475 交易位置:  11925.46 持有份额 0.037228399759449464 交易时间 2020/10/21
# 总资本 5127.682001388539 剩余资金:  4420.474190794488 交易位置:  12990.25 持有份额 0.054441431888843664 交易时间 2020/10/23
# 总资本 5143.912605374294 剩余资金:  4251.571461815865 交易位置:  13289.0 持有份额 0.06714885571212495 交易时间 2020/10/29
# 总资本 5175.428821093288 剩余资金:  4073.0927581173246 交易位置:  13758.88 持有份额 0.08011815372878922 交易时间 2020/11/2
# 总资本 5322.204713327794 剩余资金:  3865.9230572755278 交易位置:  15591.39 持有份额 0.09340293944621142 交易时间 2020/11/6
# 总资本 5392.033424756697 剩余资金:  3710.476471691528 交易位置:  16339.33 持有份额 0.10291468212375714 交易时间 2020/11/14
# 总资本 5542.166792989612 剩余资金:  3552.9312314374247 交易位置:  17798.45 持有份额 0.1117645391341486 交易时间 2020/11/19
# 总资本 5642.870847145858 剩余资金:  3406.2770796582895 交易位置:  18699.75 持有份额 0.11960554379002757 交易时间 2020/11/22
# 总资本 5653.942247575418 剩余资金:  3284.2233345857953 交易位置:  18792.52 持有份额 0.12609904967453126 交易时间 2020/12/2
# 总资本 6165.237490012847 剩余资金:  3140.004247466188 交易位置:  22847.46 持有份额 0.13241004656739344 交易时间 2020/12/18
# 总资本 6250.3697549861645 剩余资金:  3023.5600877657034 交易位置:  23490.58 持有份额 0.1373661130214946 交易时间 2020/12/21
# 总资本 6655.936459123387 剩余资金:  2900.5247184506698 交易位置:  26443.21 持有份额 0.1420179978403801 交易时间 2020/12/27
# 总资本 7016.547534144018 剩余资金:  2788.8634139612172 交易位置:  28982.56 持有份额 0.14586993420121622 交易时间 2021/1/1
# 总资本 7602.661994431797 剩余资金:  2673.706796083455 交易位置:  33000.78 持有份额 0.14935874844013816 交易时间 2021/1/4
# 总资本 8571.269647637282 剩余资金:  2560.365615351554 交易位置:  39486.04 持有份额 0.15222858590746827 交易时间 2021/1/8
# 总资本 9652.613255431057 剩余资金:  2469.1406571887273 交易位置:  46589.58 持有份额 0.1541862493339139 交易时间 2021/2/10
# 总资本 10426.389757628178 剩余资金:  2379.2070611791532 交易位置:  51608.15 持有份额 0.1559285247862794 交易时间 2021/2/19
# 总资本 11111.372420651483 剩余资金:  2283.473973099753 交易位置:  56001.2 持有份额 0.15763766575630042 交易时间 2021/2/21
# 总资本 11605.11896206086 剩余资金:  2197.507237639075 交易位置:  59133.47 持有份额 0.15909114963863588 交易时间 2021/3/15
# 总资本 12215.311551330686 剩余资金:  2070.5876507602648 交易位置:  62969.12 持有份额 0.16110633117582748 交易时间 2021/4/15
# --------------------------------------------------
# M 当前总资本 10142.096667608188 卖出价格 50110.53 卖出份额 0.16110633117582748 时间 2021/4/25
# --------------------------------------------------
# 总资本 10142.07662301441 剩余资金:  10041.853654129221 交易位置:  58280.73 持有份额 0.0017196587771839734 交易时间 2021/5/10 止损价位 46650.5157590382
# --------------------------------------------------
# M 当前总资本 10127.30750479172 卖出价格 49702.27 卖出份额 0.0017196587771839734 时间 2021/5/14
# --------------------------------------------------
# 总资本 10127.293849257785 剩余资金:  10059.0161795885 交易位置:  40188.56 持有份额 0.0016989329717035134 交易时间 2021/6/16 止损价位 28416.465201023864
# --------------------------------------------------
# M 当前总资本 10114.131434835715 卖出价格 32447.59 卖出份额 0.0016989329717035134 时间 2021/6/23
# --------------------------------------------------
# 总资本 10114.109758425853 剩余资金:  10005.727709117273 交易位置:  37318.14 持有份额 0.0029042725416803016 交易时间 2021/7/27 止损价位 30431.733950645983
# 总资本 10121.885066601417 剩余资金:  9901.246854131683 交易位置:  40002.53 持有份额 0.005515606449635397 交易时间 2021/7/29
# 总资本 10131.002604751522 剩余资金:  9805.080615185108 交易位置:  41659.06 持有份额 0.007823556017980574 交易时间 2021/8/1
# 总资本 10147.859091568458 剩余资金:  9707.314074143052 交易位置:  43816.14 持有份额 0.010054400442973892 交易时间 2021/8/9
# 总资本 10165.859742151479 剩余资金:  9611.557312163079 交易位置:  45608.37 持有份额 0.012153524232249465 交易时间 2021/8/11
# 总资本 10206.231761778614 剩余资金:  9501.329334068301 交易位置:  48932.02 持有份额 0.014405749603435783 交易时间 2021/8/22
# 总资本 10260.158217315546 剩余资金:  9358.546219238366 交易位置:  52677.4 持有份额 0.01711572701153018 交易时间 2021/9/7
# --------------------------------------------------
# M 当前总资本 10152.021332392651 卖出价格 46368.69 卖出份额 0.01711572701153018 时间 2021/9/10
# --------------------------------------------------
# 9.36852734029703

# %%
# 启动回测 模拟
print("-" * 50)
print("初始资本价值: 1000美元")
print("-" * 50)
Gold_Data = get_unit(Gold_Data.copy(), T=7, A=20, D1=55, D2=50, money=1000)
Gold_Positions, Gold_Capital,trash = reverse(Gold_Data, f=0.0001)
# Out:
# --------------------------------------------------
# 初始资本价值: 1000美元
# --------------------------------------------------
# 总资本 999.9472980594987 剩余资金:  472.9278930464991 交易位置:  1214.75 持有份额 0.4338500967384233 交易时间 2017/1/18 止损价位 1168.6511281768633
# 总资本 1011.7659084533816 剩余资金:  0.9831841644150927 交易位置:  1242.1 持有份额 0.8137692007801035 交易时间 2017/2/8
# 总资本 1024.0537250765756 剩余资金:  0 交易位置:  1257.2 持有份额 0.8145511653488511 交易时间 2017/2/25
# --------------------------------------------------
# M 当前总资本 1001.6348496437024 卖出价格 1229.8 卖出份额 0.8145511653488511 时间 2017/5/6
# --------------------------------------------------
# 总资本 1001.5571123781551 剩余资金:  224.18445690494968 交易位置:  1291.0 持有份额 0.602147680459493 交易时间 2017/6/7 止损价位 1257.7855566848016
# --------------------------------------------------
# M 当前总资本 980.0450613339923 卖出价格 1255.4 卖出份额 0.602147680459493 时间 2017/6/16
# --------------------------------------------------
# 总资本 979.9655751692693 剩余资金:  185.103927939223 交易位置:  1284.4 持有份额 0.6188583363672113 交易时间 2017/8/10 止损价位 1252.0824261309901
# 总资本 985.207362486451 剩余资金:  0 交易位置:  1292.9 持有份额 0.7620135837933721 交易时间 2017/8/19
# --------------------------------------------------
# M 当前总资本 974.3274277887471 卖出价格 1278.75 卖出份额 0.7620135837933721 时间 2017/10/7
# --------------------------------------------------
# 总资本 974.2500809581015 剩余资金:  200.781774502855 交易位置:  1312.05 持有份额 0.5895113040320464 交易时间 2017/12/31 止损价位 1278.1235937322879
# 总资本 982.925296522741 剩余资金:  0 交易位置:  1326.8 持有份额 0.7408240100412579 交易时间 2018/1/12
# --------------------------------------------------
# M 当前总资本 979.4936293187075 卖出价格 1322.3 卖出份额 0.7408240100412579 时间 2018/3/2
# --------------------------------------------------
# 总资本 979.4221669911082 剩余资金:  264.798890998185 交易位置:  1229.95 持有份额 0.5810181519516429 交易时间 2018/10/13 止损价位 1195.5276675258426
# 总资本 982.8527477538447 剩余资金:  0 交易位置:  1235.9 持有份额 0.7952526480733431 交易时间 2018/12/5
# --------------------------------------------------
# M 当前总资本 1024.5408100826578 卖出价格 1288.45 卖出份额 0.7952526480733431 时间 2019/4/5
# --------------------------------------------------
# 总资本 1024.454930437445 剩余资金:  165.65847831097028 交易位置:  1317.1 持有份额 0.6520358758837407 交易时间 2019/6/2 止损价位 1286.4268411452163
# 总资本 1036.4358263622942 剩余资金:  0 交易位置:  1335.5 持有份额 0.7760657629069967 交易时间 2019/6/6
# --------------------------------------------------
# M 当前总资本 1152.5752085979977 卖出价格 1485.3 卖出份额 0.7760657629069967 时间 2019/9/28
# --------------------------------------------------
# 总资本 1152.472985848125 剩余资金:  130.24548712150715 交易位置:  1511.5 持有份额 0.6763000322372597 交易时间 2019/12/26 止损价位 1481.9273265612035
# 总资本 1163.0102431046387 剩余资金:  0 交易位置:  1527.1 持有份额 0.7615809332097694 交易时间 2020/1/2
# --------------------------------------------------
# M 当前总资本 1132.8906539407405 卖出价格 1487.7 卖出份额 0.7615809332097694 时间 2020/3/15
# --------------------------------------------------
# 总资本 1132.8672409210985 剩余资金:  898.7370444996637 交易位置:  1741.9 持有份额 0.13441081372147348 交易时间 2020/4/11 止损价位 1593.1024483279741
# 总资本 1135.5031523227487 剩余资金:  442.8481392371011 交易位置:  1761.85 持有份额 0.39314074017972456 交易时间 2020/6/21
# 总资本 1145.7001882185457 剩余资金:  0 交易位置:  1787.9 持有份额 0.6408077567081747 交易时间 2020/7/5
# --------------------------------------------------
# M 当前总资本 1223.403937641726 卖出价格 1909.35 卖出份额 0.6408077567081747 时间 2020/9/20
# --------------------------------------------------
# 总资本 1223.3489430323011 剩余资金:  673.4028487823141 交易位置:  1943.2 持有份额 0.2830105466498492 交易时间 2021/1/2 止损价位 1872.5312555424136
# --------------------------------------------------
# M 当前总资本 1196.141801958018 卖出价格 1847.25 卖出份额 0.2830105466498492 时间 2021/1/9
# --------------------------------------------------
# 总资本 1196.0906840361276 剩余资金:  684.9114651337363 交易位置:  1787.75 持有份额 0.2859343973723347 交易时间 2021/4/22 止损价位 1717.803885843064
# 总资本 1209.9871942620139 剩余资金:  113.97071792904035 交易位置:  1836.55 持有份额 0.5967800911126697 交易时间 2021/5/7
# 总资本 1240.948685058562 剩余资金:  0 交易位置:  1888.45 持有份额 0.6571255183131997 交易时间 2021/5/19
# --------------------------------------------------
# M 当前总资本 1158.4949965281564 卖出价格 1763.15 卖出份额 0.6571255183131997 时间 2021/6/30
# --------------------------------------------------
# 2.6750337090598264

# %% [markdown]
# ## 动态投资组合交易

# %%
weight_data = Vol_Data[['Date','W0','W1']]
weight_data.index = weight_data['Date']

# %%
test_list = np.random.uniform(0,1,3).tolist()+[1]*15+np.random.uniform(0,1,3).tolist()+[1]*20+[0,1]+[1]*17
weight_data['W0'] = np.round(test_list,2)
weight_data['W1'] = 1-weight_data['W0'] 
weight_data.loc['2020-02-23']['W0']=0
weight_data.loc['2020-02-23']['W1']=1
weight_data.loc['2020-03-24']['W0']=1
weight_data.loc['2020-03-24']['W1']=0

# %%
Bitcoin_Data = get_unit(Bitcoin_Data.copy(), T=7, A=20, D1=20, D2=300, money=1000)
Gold_Data = get_unit(Gold_Data.copy(), T=7, A=20, D1=55, D2=50, money=1000)

# %%
close_date = positions
capital_residual = 1000  # 初始本金
fee_bit, fee_gold = 0.0002, 0.0001  # 佣金
fee_bit_sum, fee_gold_sum = 0, 0  # 总交易成本
sold_change_unit_bit = 0  # 持仓比例改变时，仓位改变份额
sold_change_unit_Gold = 0
W0, W1 = 0.5, 0.5
capital_residual_Bit = capital_residual * W0
capital_residual_Gold = capital_residual * W1
positions_Bit, positions_Gold = [], []
unit_position = [0, 0]
period = pd.date_range(start='2016/09/11', end='2021/09/10')
for i in period:
    if i in weight_data['Date']:

        # 达到时间点，更改权重
        weight_change = weight_data.loc[i]
        W0, W1 = weight_change['W0'], 1 - weight_change['W0']
        # 计算当天持有份额的价值
        capital_hold_Bit = unit_position[0] * Bitcoin_Data.loc[i]['Value']
        capital_hold_Gold = unit_position[1] * Gold_Data.loc[i]['Value']
        # 计算总资本价值
        capital_all = capital_hold_Bit + capital_residual_Bit + capital_hold_Gold + capital_residual_Gold
        # 按比列分配资产组合, 计算需要调整的资本
        capital_change_Bit, capital_change_Gold = capital_all * W0, capital_all * W1
        share_adj_Bit = capital_change_Bit - (capital_hold_Bit +
                                              capital_residual_Bit)
        # 判断是否需要调整资产持有份额
        if share_adj_Bit > 0:
            # 比特币资产比例提高时，黄金资产需要降低份额
            # 判断黄金资产账户，是否剩余足够的资金
            if capital_residual_Gold - share_adj_Bit >= 0:
                # 如果剩余资金足够，划入对应资金比特币账户
                capital_residual_Gold -= share_adj_Bit
                # 比特币账户增持
                capital_residual_Bit += share_adj_Bit
            elif capital_residual_Gold - share_adj_Bit < 0:
                # 黄金资产账户剩余资金不足时，判断如何售出
                if capital_residual_Gold == 0:
                    # 如果黄金账户没有钱，则在下次开市时卖出当前价格对应价值的份额
                    sold_change_unit_Gold = share_adj_Bit / (
                        Gold_Data.loc[i]["Value"] * (1 + fee_gold))
                    # 总仓位同时降低
                    unit_position[1] -= sold_change_unit_Gold
                elif capital_residual_Gold > 0:
                    # 剩下的钱先划走，不够的卖份额
                    sold_change_unit_Gold = (share_adj_Bit -
                                             capital_residual_Gold) / (
                                                 Gold_Data.loc[i]["Value"] *
                                                 (1 + fee_gold))
                    capital_residual_Gold = 0
                    # 总仓位同时降低
                    unit_position[1] -= sold_change_unit_Gold
        elif share_adj_Bit < 0:
            # 黄金资产提高时，比特币资产需要降低份额
            # 判断比特币资产账户，是否剩余足够的资金
            if capital_residual_Bit - np.abs(share_adj_Bit) >= 0:
                # 如果剩余资金足够，划入对应资金黄金账户
                capital_residual_Bit -= np.abs(share_adj_Bit)
                # 黄金账户增持
                capital_residual_Gold += np.abs(share_adj_Bit)
            elif capital_residual_Bit - np.abs(share_adj_Bit) < 0:
                # 比特币资产账户剩余资金不足时，判断如何售出
                if capital_residual_Bit == 0:
                    # 如果比特币账户没有钱，则在下次开市时卖出当前价格对应价值的份额
                    sold_change_unit_bit = np.abs(share_adj_Bit) / (
                        Bitcoin_Data.loc[i]["Value"] * (1 + fee_bit))
                    # 总仓位同时降低
                    unit_position[0] -= sold_change_unit_bit
                elif capital_residual_Bit > 0:
                    # 剩下的钱先划走，不够的卖份额
                    sold_change_unit_bit = (np.abs(share_adj_Bit) -
                                            capital_residual_Bit) / (
                                                Bitcoin_Data.loc[i]["Value"] *
                                                (1 + fee_bit))
                    capital_residual_Bit = 0
                    # 总仓位同时降低
                    unit_position[0] -= sold_change_unit_bit
        print('仓位转换',i,capital_residual_Bit,capital_residual_Gold)
    if i not in close_date:
        # 黄金未闭市时间
        # 黄金交易
        if sold_change_unit_Gold != 0:
            price = Gold_Data.loc[i]['Value']
            capital_residual_Bit += sold_change_unit_Gold * price * (1 -
                                                                     fee_gold)
            fee_gold_sum += sold_change_unit_Gold * price * fee_gold
            print('售出比特币：',sold_change_unit_Gold)
            sold_change_unit_Gold = 0
        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Gold_Data.loc[i]["Value Shift"] > Gold_Data.loc[i]["upper_bound"]
                and unit_position[1] == 0 and capital_residual_Gold > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Gold_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Gold_Data.loc[i]['Unit']
            if capital_buy > capital_residual_Gold:
                unit_position[1] += capital_residual_Gold / (price *
                                                             (1 + fee_bit))
                fee_gold_sum += capital_residual_Gold * fee_gold / (1 +
                                                                    fee_bit)
                capital_buy = capital_residual_Gold
                capital_residual_Gold = 0
            else:
                unit_position[1] += Gold_Data.loc[i]['Unit']
                # 剩余资金量
                capital_residual_Gold = capital_residual_Gold - capital_buy * (
                    1 + fee_gold)
                # 记录消耗费用
                fee_gold_sum += capital_buy * fee_gold
            # 总资产
            capital_all = capital_residual_Gold + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_gold = price - 2.0 * Gold_Data.loc[i]['ATR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Gold_Data.loc[i]["ATR"]
            positions_Gold += [{
                "Date": Gold_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[1]
            }]
            print('黄金建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Gold,
                  "交易位置: ", price, "持有份额", unit_position[1], "交易时间",
                  Gold_Data.loc[i]['Date'], "止损价位", stop_loss_gold)
        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[1] > 0 and capital_residual_Gold > 0 and (
                Gold_Data.loc[i]["Value Shift"] > positions_Gold[-1]['Price'] +
                0.5 * Gold_Data.loc[i]["ATR"]) and (
                    i != pd.to_datetime('2021/09/10')):
            if unit_position[1] > 4 or capital_residual_Gold <= 0:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Gold_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Gold_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_gold)) <= capital_residual_Gold:
                    unit_position[1] += Gold_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Gold -= capital_buy * (1 + fee_gold)
                    # 记录消耗费用
                    fee_gold_sum += capital_buy * fee_gold
                # 若不充足
                elif (capital_buy * (1 + fee_gold)) > capital_residual_Gold:
                    # 剩下的钱全部购买
                    unit_position[1] += capital_residual_Gold / (
                        price * (1 + fee_gold))
                    # 记录消耗费用
                    fee_gold_sum += capital_buy * fee_gold
                    capital_residual_Gold = 0
                capital_all = capital_residual_Gold + unit_position[1] * price
                positions_Gold += [{
                    "Date": Gold_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[1]
                }]
                # stop_loss_gold = price - (2.0 - 0.5) * Gold_Data.loc[i]["ATR"]
            print('黄金加仓', "总资本", capital_all, "剩余资金: ", capital_residual_Gold,
                  "交易位置: ", price, "持有份额", unit_position[1], "交易时间",
                  Gold_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[1] > 0 and (
                Gold_Data.loc[i]["Value Shift"] <
                Gold_Data.loc[i]["lower_bound"]
                or Gold_Data.loc[i]["Value Shift"] < stop_loss_gold
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Gold_Data.loc[i]['Value']
            capital_sell = unit_position[1] * price * (1 - fee_gold)
            fee_gold_sum += unit_position[1] * price * fee_gold
            capital_residual_Gold = capital_sell + capital_residual_Gold
            capital_all = capital_residual_Gold
            print('-' * 50)
            print('M黄金', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[1], "时间", Gold_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_gold, unit_position[1] = 0.0, 0.0

        ###############################################
        ###############################################
        # 比特币交易
        if sold_change_unit_bit != 0:
            price = Bitcoin_Data.loc[i]['Value']
            capital_residual_Gold += sold_change_unit_bit * price * (1 -
                                                                     fee_bit)
            fee_bit_sum += sold_change_unit_bit * price * fee_bit
            print('售出黄金：',sold_change_unit_bit)
            sold_change_unit_bit = 0

        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Bitcoin_Data.loc[i]["Value Shift"] >
                Bitcoin_Data.loc[i]["upper_bound"] and unit_position[0] == 0
                and capital_residual_Bit > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Bitcoin_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Bitcoin_Data.loc[i]['Unit']
            unit_position[0] += Bitcoin_Data.loc[i]['Unit']
            # 剩余资金量
            capital_residual_Bit = capital_residual_Bit - capital_buy * (
                1 + fee_bit)
            # 记录消耗费用
            fee_bit_sum += capital_buy * fee_bit
            # 总资产
            capital_all = capital_residual_Bit + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_bit = price - 2.0 * Bitcoin_Data.loc[i]['ATR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Bitcoin_Data.loc[i]["ATR"]
            positions_Bit += [{
                "Date": Bitcoin_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[0]
            }]
            print('比特币建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'], "止损价位", stop_loss_bit)

        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[0] > 0 and capital_residual_Bit > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] >
                positions_Bit[-1]['Price'] + 0.5 * Bitcoin_Data.loc[i]["ATR"]
        ) and (i != pd.to_datetime('2021/09/10')):
            if unit_position[0] > 4:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Bitcoin_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Bitcoin_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_bit)) <= capital_residual_Bit:
                    unit_position[0] += Bitcoin_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Bit -= capital_buy * (1 + fee_bit)
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                # 若不充足
                elif (capital_buy * (1 + fee_bit)) > capital_residual_Bit:
                    # 剩下的钱全部购买
                    unit_position[0] += capital_residual_Bit / (price *
                                                                (1 + fee_bit))
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                    capital_residual_Bit = 0
                capital_all = capital_residual_Bit + unit_position[0] * price
                positions_Bit += [{
                    "Date": Bitcoin_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[0]
                }]
                # stop_loss = price - (2.0 - 0.5) * Bitcoin_Data.loc[i]["ATR"]
            print("比特币加仓", "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[0] > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] <
                Bitcoin_Data.loc[i]["lower_bound"]
                or Bitcoin_Data.loc[i]["Value Shift"] < stop_loss_bit
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Bitcoin_Data.loc[i]['Value']
            capital_sell = unit_position[0] * price * (1 - fee_bit)
            fee_bit_sum += unit_position[0] * price * fee_bit
            capital_residual_Bit = capital_sell + capital_residual_Bit
            capital_all = capital_residual_Bit
            print('-' * 50)
            print('M比特币', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[0], "时间", Bitcoin_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_bit, unit_position[0] = 0.0, 0.0
    ###############################################
    ###############################################
    else:
        # 黄金闭市时间
        # 仅交易比特币
        if sold_change_unit_bit != 0:
            price = Bitcoin_Data.loc[i]['Value']
            capital_residual_Gold += sold_change_unit_bit * price * (1 -
                                                                     fee_bit)
            fee_bit_sum += sold_change_unit_bit * price * fee_bit
            print('售出黄金：',sold_change_unit_bit)
            sold_change_unit_bit = 0

        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Bitcoin_Data.loc[i]["Value Shift"] >
                Bitcoin_Data.loc[i]["upper_bound"] and unit_position[0] == 0
                and capital_residual_Bit > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Bitcoin_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Bitcoin_Data.loc[i]['Unit']
            unit_position[0] += Bitcoin_Data.loc[i]['Unit']
            # 剩余资金量
            capital_residual_Bit = capital_residual_Bit - capital_buy * (
                1 + fee_bit)
            # 记录消耗费用
            fee_bit_sum += capital_buy * fee_bit
            # 总资产
            capital_all = capital_residual_Bit + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_bit = price - 2.0 * Bitcoin_Data.loc[i]['ATR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Bitcoin_Data.loc[i]["ATR"]
            # positions_Bit[-1]['Price'] + 0.5 * Bitcoin_Data.loc[i]["ATR"]
            positions_Bit += [{
                "Date": Bitcoin_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[0]
            }]
            print('比特币建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'], "止损价位", stop_loss_bit)

        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[0] > 0 and capital_residual_Bit > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] >begin_chance
        ) and (i != pd.to_datetime('2021/09/10')):
            if unit_position[0] > 5 or capital_residual_Bit <= 0:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Bitcoin_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Bitcoin_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_bit)) <= capital_residual_Bit:
                    unit_position[0] += Bitcoin_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Bit -= capital_buy * (1 + fee_bit)
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                # 若不充足
                elif (capital_buy * (1 + fee_bit)) > capital_residual_Bit:
                    # 剩下的钱全部购买
                    unit_position[0] += capital_residual_Bit / (price *
                                                                (1 + fee_bit))
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                    capital_residual_Bit = 0
                capital_all = capital_residual_Bit + unit_position[0] * price
                positions_Bit += [{
                    "Date": Bitcoin_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[0]
                }]
                # stop_loss_bit = price - (2.0 - 0.5) * Bitcoin_Data.loc[i]["ATR"]
            print('比特币加仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[0] > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] <
                Bitcoin_Data.loc[i]["lower_bound"]
                or Bitcoin_Data.loc[i]["Value Shift"] < stop_loss_bit
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Bitcoin_Data.loc[i]['Value']
            capital_sell = unit_position[0] * price * (1 - fee_bit)
            fee_bit_sum += unit_position[0] * price * fee_bit
            capital_residual_Bit += capital_sell
            capital_all = capital_residual_Bit
            print('-' * 50)
            print('M比特币', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[0], "时间", Bitcoin_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_bit, unit_position[0] = 0.0, 0.0
# Out:
# 比特币建仓 总资本 499.8951313544866 剩余资金:  -24.44809621289528 交易位置:  614.74 持有份额 0.8529512111907178 交易时间 2016/10/8 止损价位 591.2919999999999
# 仓位转换 2016-10-11 00:00:00 15.588372637326529 459.9635311497782
# 比特币加仓 总资本 558.0281078550582 剩余资金:  0 交易位置:  635.96 持有份额 0.877457871336339 交易时间 2016/10/13
# 仓位转换 2016-11-10 00:00:00 0 459.9635311497782
# 售出黄金： 0.5440561082502838
# 仓位转换 2016-12-10 00:00:00 597.3896551566004 255.031850799337
# 比特币加仓 总资本 853.747751811004 剩余资金:  324.67862475810296 交易位置:  769.08 持有份额 0.6879246984096596 交易时间 2016/12/10
# 比特币加仓 总资本 859.1397417795274 剩余资金:  42.75403671058933 交易位置:  777.0 持有份额 1.0506894531131765 交易时间 2016/12/11
# 比特币加仓 总资本 871.4242592834291 剩余资金:  0 交易位置:  788.7 持有份额 1.1048868508728655 交易时间 2016/12/17
# 仓位转换 2017-01-09 00:00:00 255.031850799337 0.0
# 比特币加仓 总资本 1260.9996310054996 剩余资金:  151.76797679030113 交易位置:  910.49 持有份额 1.2182798868907934 交易时间 2017/1/9
# 比特币加仓 总资本 1148.1969302764192 剩余资金:  80.0096243363367 交易位置:  817.91 持有份额 1.305996143756749 交易时间 2017/1/14
# 比特币加仓 总资本 1150.324483870308 剩余资金:  8.594934893227759 交易位置:  819.55 持有份额 1.3931176242780556 交易时间 2017/1/15
# 比特币加仓 总资本 1271.593654420463 剩余资金:  0 交易位置:  906.6 持有份额 1.4025961332676626 交易时间 2017/1/18
# 仓位转换 2017-02-08 00:00:00 0 0.0
# 仓位转换 2017-03-10 00:00:00 0 0.0
# 仓位转换 2017-04-09 00:00:00 0 0.0
# 仓位转换 2017-05-09 00:00:00 0 0.0
# 仓位转换 2017-06-08 00:00:00 0 0.0
# 仓位转换 2017-07-08 00:00:00 0 0.0
# 仓位转换 2017-08-07 00:00:00 0 0.0
# 仓位转换 2017-09-06 00:00:00 0 0.0
# 仓位转换 2017-10-06 00:00:00 0 0.0
# 仓位转换 2017-11-05 00:00:00 0 0.0
# 仓位转换 2017-12-05 00:00:00 0 0.0
# 仓位转换 2018-01-04 00:00:00 0 0.0
# 仓位转换 2018-02-03 00:00:00 0 0.0
# 仓位转换 2018-03-05 00:00:00 0 0.0
# 仓位转换 2018-04-04 00:00:00 0 0.0
# 售出黄金： 1.290130416522945
# 仓位转换 2018-05-04 00:00:00 0 9579.21151015218
# 售出黄金： 0.09055537580276407
# 仓位转换 2018-06-03 00:00:00 4190.797706523446 6271.455434559704
# 比特币加仓 总资本 4358.108913099767 剩余资金:  4085.1033463292065 交易位置:  7637.14 持有份额 0.035747094693898626 交易时间 2018/6/3
# 比特币加仓 总资本 4357.311109452306 剩余资金:  3956.7456695593364 交易位置:  7615.54 持有份额 0.05259842898769741 交易时间 2018/6/9
# 比特币加仓 总资本 4313.175676793091 剩余资金:  3838.359461546302 交易位置:  6776.888333 持有份额 0.07006404590358606 交易时间 2018/6/10
# 比特币加仓 总资本 4294.418128700263 剩余资金:  3747.8331161277133 交易位置:  6509.426667 持有份额 0.08396822647123466 交易时间 2018/6/16
# 比特币加仓 总资本 4290.620125932441 剩余资金:  3656.949676973573 交易位置:  6464.411667 持有份额 0.09802445784721216 交易时间 2018/6/17
# 比特币加仓 总资本 4258.957924636234 剩余资金:  3560.258200345437 交易位置:  6141.605833 持有份额 0.11376498969317633 交易时间 2018/6/23
# 比特币加仓 总资本 4262.221068771072 剩余资金:  3462.989367857488 交易位置:  6170.46 持有份额 0.1295254650242581 交易时间 2018/6/24
# 比特币加仓 总资本 4269.0418156531105 剩余资金:  3359.027676967013 交易位置:  6223.28 持有份额 0.1462274136285203 交易时间 2018/6/30
# 比特币加仓 总资本 4291.16967957518 剩余资金:  3249.9471158434703 交易位置:  6374.754167 持有份额 0.16333532814830354 交易时间 2018/7/1
# 仓位转换 2018-07-03 00:00:00 9521.402550403174 0.0
# 比特币加仓 总资本 10598.459273849741 剩余资金:  9409.19743776674 交易位置:  6594.281667 持有份额 0.18034744285104892 交易时间 2018/7/7
# 比特币加仓 总资本 10627.160908888869 剩余资金:  9290.899835079816 交易位置:  6753.559167 持有份额 0.1978602749700399 交易时间 2018/7/8
# 比特币加仓 总资本 10525.721319629942 剩余资金:  9168.417654084657 交易位置:  6241.0 持有份额 0.2174817602219654 交易时间 2018/7/14
# 比特币加仓 总资本 10527.401861333663 剩余资金:  9045.816656683139 交易位置:  6248.84 持有份额 0.23709763806570874 交易时间 2018/7/15
# 比特币加仓 总资本 10674.628626718466 剩余资金:  8907.478039498188 交易位置:  6869.910833 持有份额 0.2572304983540211 交易时间 2018/7/17
# 比特币加仓 总资本 10810.030329521931 剩余资金:  8768.466216794497 交易位置:  7396.401667 持有份额 0.27602126069439076 交易时间 2018/7/19
# 比特币加仓 总资本 10793.054728565778 剩余资金:  8645.065494248736 交易位置:  7334.99 持有份额 0.292841467311754 交易时间 2018/7/21
# 比特币加仓 总资本 10827.088055640645 剩余资金:  8525.583419871431 交易位置:  7451.289167 持有份额 0.30887334851558756 交易时间 2018/7/22
# 比特币加仓 总资本 11054.404448017556 剩余资金:  8399.544728381125 交易位置:  8187.324167 持有份额 0.3242646395188754 交易时间 2018/7/26
# 比特币加仓 总资本 11052.735396955492 剩余资金:  8278.427119178725 交易位置:  8182.251667 持有份额 0.33906415870412343 交易时间 2018/7/28
# 比特币加仓 总资本 11060.87938372216 剩余资金:  8158.058967798896 交易位置:  8206.341667 持有份额 0.35372892498448105 交易时间 2018/7/29
# 仓位转换 2018-08-02 00:00:00 8158.058967798896 0.0
# 比特币加仓 总资本 10721.782623284693 剩余资金:  8048.334563392355 交易位置:  7247.769167 持有份额 0.3688649566910712 交易时间 2018/8/4
# 比特币加仓 总资本 10634.529322662916 剩余资金:  7944.642437051265 交易位置:  7011.28 持有份额 0.3836513283753682 交易时间 2018/8/5
# 比特币加仓 总资本 10299.845968583371 剩余资金:  7861.489254022287 交易位置:  6138.96 持有份额 0.39719377786483123 交易时间 2018/8/11
# 比特币加仓 总资本 10368.21454339514 剩余资金:  7776.772087736227 交易位置:  6311.131667 持有份额 0.4106145446480212 交易时间 2018/8/12
# 比特币加仓 总资本 10419.764223282285 剩余资金:  7681.4614160660685 交易位置:  6436.720833 持有份额 0.4254189172190585 交易时间 2018/8/18
# 比特币加仓 总资本 10405.85142839152 剩余资金:  7583.058731045079 交易位置:  6404.063333 持有份额 0.4407815086400927 交易时间 2018/8/19
# 比特币加仓 总资本 10544.833904530247 剩余资金:  7458.1329741446725 交易位置:  6719.429231 持有份额 0.45936951253911873 交易时间 2018/8/25
# 比特币加仓 总资本 10553.463319555522 剩余资金:  7330.808283706176 交易位置:  6738.27 持有份额 0.47826148786696676 交易时间 2018/8/26
# 比特币加仓 总资本 10544.348769747903 剩余资金:  7202.071819241164 交易位置:  6719.266154 持有份额 0.49741696100504534 交易时间 2018/8/27
# 比特币加仓 总资本 10722.856440445998 剩余资金:  7066.354623892116 交易位置:  7078.19 持有份额 0.5165871241876642 交易时间 2018/8/29
# 仓位转换 2018-09-01 00:00:00 7066.354623892116 0.0
# 比特币加仓 总资本 10692.139170988608 剩余资金:  6932.18574848008 交易位置:  7018.78 持有份额 0.5356989993287335 交易时间 2018/9/1
# 比特币加仓 总资本 10814.86933515919 剩余资金:  6791.426278669252 交易位置:  7247.935385 持有份额 0.5551157457635004 交易时间 2018/9/2
# 比特币加仓 总资本 10325.328435470525 剩余资金:  6669.62356379214 交易位置:  6366.1075 持有份额 0.5742449168001614 交易时间 2018/9/8
# 比特币加仓 总资本 10279.548427772408 剩余资金:  6553.523042315701 交易位置:  6286.425833 持有份额 0.5927096707157965 交易时间 2018/9/9
# 比特币加仓 总资本 10417.169285421463 剩余资金:  6435.422156271829 交易位置:  6518.655 持有份额 0.6108234181974095 交易时间 2018/9/15
# 比特币加仓 总资本 10419.426479726852 剩余资金:  6314.242117214193 交易位置:  6522.39 持有份额 0.6293987882528734 交易时间 2018/9/16
# 比特币加仓 总资本 10566.506926668379 剩余资金:  6169.554001281491 交易位置:  6756.12 持有份额 0.6508103653260876 交易时间 2018/9/22
# 比特币加仓 总资本 10536.752403748049 剩余资金:  6025.727821495811 交易位置:  6710.445 持有份额 0.6722392601760744 交易时间 2018/9/23
# 比特币加仓 总资本 10429.183990002046 剩余资金:  5877.001480511648 交易位置:  6550.474167 持有份额 0.6949393881168783 交易时间 2018/9/29
# 比特币加仓 总资本 10458.800059494348 剩余资金:  5723.852410449724 交易位置:  6593.135 持有份额 0.7181633091154094 交易时间 2018/9/30
# 仓位转换 2018-10-01 00:00:00 5723.852410449724 0.0
# 比特币加仓 总资本 10450.399090230245 剩余资金:  5545.997390831316 交易位置:  6581.486667 持有份额 0.745181438107277 交易时间 2018/10/6
# 比特币加仓 总资本 10444.500338081263 剩余资金:  5362.671128858935 交易位置:  6573.62 持有份额 0.7730640361356952 交易时间 2018/10/7
# 比特币加仓 总资本 10191.96371162695 剩余资金:  5170.377819520416 交易位置:  6247.0 持有份额 0.8038395857381997 交易时间 2018/10/13
# 比特币加仓 总资本 10234.045787735286 剩余资金:  4978.096441089875 交易位置:  6299.399167 持有份额 0.8343572469862207 交易时间 2018/10/14
# 比特币加仓 总资本 10481.70788664827 剩余资金:  4781.223804934032 交易位置:  6596.276154 持有份额 0.8641973059689821 交易时间 2018/10/17
# 比特币加仓 总资本 10388.81116230731 剩余资金:  4588.953322234861 交易位置:  6488.825833 持有份额 0.8938223939647617 交易时间 2018/10/20
# 比特币加仓 总资本 10427.006243006832 剩余资金:  4394.326153596487 交易位置:  6531.601667 持有份额 0.923614206281074 交易时间 2018/10/21
# 比特币加仓 总资本 10366.29169714374 剩余资金:  4155.697966739206 交易位置:  6465.9175 持有份额 0.9605123681835617 交易时间 2018/10/27
# 比特币加仓 总资本 10357.878507646332 剩余资金:  3908.0081814343102 交易位置:  6457.21 持有份额 0.9988633366751308 交易时间 2018/10/28
# 仓位转换 2018-10-31 00:00:00 3908.0081814343102 0.0
# 比特币加仓 总资本 10291.1093774151 剩余资金:  3632.713259961159 交易位置:  6390.42 持有份额 1.041934038365857 交易时间 2018/11/3
# 比特币加仓 总资本 10292.567670815752 剩余资金:  3352.738670599691 交易位置:  6391.873333 持有份额 1.0857269283461974 交易时间 2018/11/4
# 比特币加仓 总资本 10394.975653529515 剩余资金:  3047.097742182204 交易位置:  6486.251667 持有份额 1.1328388549477646 交易时间 2018/11/8
# 比特币加仓 总资本 10296.109258065919 剩余资金:  2736.6464414196753 交易位置:  6399.033333 持有份额 1.1813444974042993 交易时间 2018/11/10
# 比特币加仓 总资本 10271.51586114072 剩余资金:  2422.6914799994183 交易位置:  6378.268333 持有份额 1.2305572565100331 交易时间 2018/11/11
# --------------------------------------------------
# M比特币 当前总资本 9307.749482643501 卖出价格 5596.1925 卖出份额 1.2305572565100331 时间 2018/11/16
# --------------------------------------------------
# 仓位转换 2018-11-30 00:00:00 9307.749482643501 0.0
# 仓位转换 2018-12-30 00:00:00 9307.749482643501 0.0
# 仓位转换 2019-01-29 00:00:00 9307.749482643501 0.0
# 比特币建仓 总资本 9307.713982097095 剩余资金:  9130.211250065578 交易位置:  3686.29 持有份额 0.04815213453947358 交易时间 2019/2/11 止损价位 3270.939773238928
# 比特币加仓 总资本 9319.243302512774 剩余资金:  8936.430571253242 交易位置:  3926.53 持有份额 0.09749390206098787 交易时间 2019/2/20
# 比特币加仓 总资本 9324.760298307716 剩余资金:  8759.985652173285 交易位置:  3983.48 持有份额 0.14177920966954297 交易时间 2019/2/23
# 比特币加仓 总资本 9346.85932015612 剩余资金:  8582.208277780743 交易位置:  4139.6 持有份额 0.18471616638694005 交易时间 2019/2/24
# 仓位转换 2019-02-28 00:00:00 8582.208277780743 0.0
# 比特币加仓 总资本 9290.496558666702 剩余资金:  8442.054929073813 交易位置:  3834.62 持有份额 0.22125833318370242 交易时间 2019/3/2
# 比特币加仓 总资本 9289.765453115848 剩余资金:  8304.507168381955 交易位置:  3831.44 持有份额 0.25715091055422856 交易时间 2019/3/3
# 比特币加仓 总资本 9301.180918388256 剩余资金:  8140.007947778748 交易位置:  3875.96 持有份额 0.29958332145055877 交易时间 2019/3/9
# 比特币加仓 总资本 9323.495730203993 剩余资金:  7969.454021443054 交易位置:  3950.56 持有份额 0.3427467773583842 交易时间 2019/3/10
# 比特币加仓 总资本 9318.637684824527 剩余资金:  7774.28654672046 交易位置:  3936.5 持有份额 0.3923157978163513 交易时间 2019/3/16
# 比特币加仓 总资本 9349.766047202871 剩余资金:  7568.606628135426 交易位置:  4015.95 持有份额 0.4435213135291636 交易时间 2019/3/17
# 比特币加仓 总资本 9342.230883576474 剩余资金:  7348.119335048897 交易位置:  3999.06 持有份额 0.4986450687230443 交易时间 2019/3/23
# 比特币加仓 总资本 9348.59775034137 剩余资金:  7119.529531822375 交易位置:  4011.92 持有份额 0.5556113328578326 交易时间 2019/3/24
# 仓位转换 2019-03-30 00:00:00 7119.529531822375 0.0
# 比特币加仓 总资本 9406.12289162037 剩余资金:  6855.170945387355 交易位置:  4115.55 持有份额 0.6198325731027483 交易时间 2019/3/30
# 比特币加仓 总资本 9405.382433864424 剩余资金:  6592.900502782899 交易位置:  4114.44 持有份额 0.6835637246093093 交易时间 2019/3/31
# 比特币加仓 总资本 9983.195989940494 剩余资金:  6339.300808466345 交易位置:  4959.81 持有份额 0.7346844297410884 交易时间 2019/4/4
# 比特币加仓 总资本 10033.821534397395 剩余资金:  6147.793424433623 交易位置:  5028.77 持有份额 0.7727591657530116 交易时间 2019/4/6
# 比特币加仓 总资本 10052.913090422648 剩余资金:  5976.592555436651 交易位置:  5053.52 持有份额 0.8066299401181745 交易时间 2019/4/7
# 比特币加仓 总资本 10151.527432140145 剩余资金:  5834.395824003784 交易位置:  5175.81 持有份额 0.8340977756402113 交易时间 2019/4/10
# 比特币加仓 总资本 10065.620643193113 剩余资金:  5693.9579064513055 交易位置:  5072.85 持有份额 0.8617764642640343 交易时间 2019/4/13
# 比特币加仓 总资本 10058.49984826835 剩余资金:  5552.0564124765 交易位置:  5064.62 持有份额 0.8897890534318171 交易时间 2019/4/14
# 比特币加仓 总资本 10246.827696623173 剩余资金:  5394.042985321819 交易位置:  5276.31 持有份额 0.9197307799013617 交易时间 2019/4/19
# 比特币加仓 总资本 10247.467049022376 剩余资金:  5233.755583629288 交易位置:  5277.04 持有份额 0.9500991967832513 交易时间 2019/4/20
# 比特币加仓 总资本 10278.065561358873 剩余资金:  5070.294058888088 交易位置:  5309.28 持有份额 0.9808809297062474 交易时间 2019/4/21
# 比特币加仓 总资本 10251.10760190272 剩余资金:  4906.371602372682 交易位置:  5281.83 持有份额 1.0119098872038743 交易时间 2019/4/22
# 比特币加仓 总资本 10405.24736929082 剩余资金:  4732.221647930979 交易位置:  5434.19 持有份额 1.0439505650998293 交易时间 2019/4/25
# 比特币加仓 总资本 10257.64029157151 剩余资金:  4561.058238099107 交易位置:  5292.83 持有份额 1.076282830446548 交易时间 2019/4/27
# 比特币加仓 总资本 10244.00200553744 剩余资金:  4390.668880924269 交易位置:  5280.19 持有份额 1.1085459281982604 交易时间 2019/4/28
# 仓位转换 2019-04-29 00:00:00 4390.668880924269 0.0
# 比特币加仓 总资本 10661.829479337543 剩余资金:  4196.060795922035 交易位置:  5657.14 持有份额 1.142939485926724 交易时间 2019/5/4
# 比特币加仓 总资本 10792.017015719752 剩余资金:  4001.078585869333 交易位置:  5771.08 持有份额 1.176718816902628 交易时间 2019/5/5
# 比特币加仓 总资本 10729.119418605227 剩余资金:  3814.651730027748 交易位置:  5717.66 持有份额 1.2093177433735969 交易时间 2019/5/6
# 比特币加仓 总资本 11248.183196625116 剩余资金:  3635.2992505622497 交易位置:  6146.91 持有份额 1.2384895737960806 交易时间 2019/5/10
# 比特币加仓 总资本 11497.2195754465 剩余资金:  3453.9661674633944 交易位置:  6348.02 持有份额 1.2670491598928648 交易时间 2019/5/11
# 比特币加仓 总资本 12637.8916353649 剩余资金:  3255.7853314912427 交易位置:  7248.31 持有份额 1.2943853538098753 交易时间 2019/5/12
# 比特币加仓 总资本 13601.37775426738 剩余资金:  3113.5030481579147 交易位置:  7992.69 持有份额 1.3121833457959042 交易时间 2019/5/15
# 比特币加仓 总资本 12774.066280025432 剩余资金:  3017.282717920765 交易位置:  7362.22 持有份额 1.3252502047079098 交易时间 2019/5/18
# 比特币加仓 总资本 12645.273288795637 剩余资金:  2925.120097440839 交易位置:  7265.05 持有份额 1.3379334197775374 交易时间 2019/5/19
# 比特币加仓 总资本 13637.973526686097 剩余资金:  2827.0959161427472 交易位置:  8007.03 持有份额 1.3501732365862686 交易时间 2019/5/21
# 比特币加仓 总资本 13632.864292683207 剩余资金:  2731.672330445984 交易位置:  8003.26 持有份额 1.3620939419982887 交易时间 2019/5/25
# 比特币加仓 总资本 13725.726337532786 剩余资金:  2635.9479129602505 交易位置:  8071.45 持有份额 1.3739512014040272 交易时间 2019/5/26
# 比特币加仓 总资本 14650.333196120653 剩余资金:  2530.519726540883 交易位置:  8744.42 持有份额 1.386005414833662 交易时间 2019/5/27
# 仓位转换 2019-05-29 00:00:00 2530.519726540883 0.0
# 比特币加仓 总资本 14386.127011743501 剩余资金:  2432.0387557544923 交易位置:  8553.81 持有份额 1.3975162244647719 交易时间 2019/6/1
# 比特币加仓 总资本 14387.490663511597 剩余资金:  2332.5723958381277 交易位置:  8554.8 持有份额 1.4091408645057126 交易时间 2019/6/2
# 比特币加仓 总资本 13603.27084851398 剩余资金:  2238.3911056172524 交易位置:  7998.29 持有份额 1.4209136881629356 交易时间 2019/6/8
# 比特币加仓 总资本 13508.122234360031 剩余资金:  2146.1590056871037 交易位置:  7931.34 持有份额 1.4325401796761867 交易时间 2019/6/9
# 比特币加仓 总资本 14600.068080136489 剩余资金:  2034.9788565365868 交易位置:  8693.6 持有份额 1.445326357734414 交易时间 2019/6/15
# 比特币加仓 总资本 14839.782093027814 剩余资金:  1923.6062560636337 交易位置:  8859.47 持有份额 1.4578948669575247 交易时间 2019/6/16
# 比特币加仓 总资本 15155.70133488102 剩余资金:  1817.8112754962726 交易位置:  9076.18 持有份额 1.4695488696108656 交易时间 2019/6/19
# 比特币加仓 总资本 16820.97094838281 剩余资金:  1701.960403740871 交易位置:  10209.38 持有份额 1.48089409392558 交易时间 2019/6/22
# 比特币加仓 总资本 17501.047980085074 剩余资金:  1584.0321575270812 交易位置:  10668.63 持有份额 1.4919456221237397 交易时间 2019/6/23
# 比特币加仓 总资本 20878.67009137156 剩余资金:  1466.9009765282622 交易位置:  12932.55 持有份额 1.5010008942430766 交易时间 2019/6/27
# 仓位转换 2019-06-28 00:00:00 1466.9009765282622 0.0
# 比特币加仓 总资本 20040.792271974442 剩余资金:  1371.2807031221994 交易位置:  12374.35 持有份额 1.5087266457512711 交易时间 2019/6/29
# 比特币加仓 总资本 19310.59612805728 剩余资金:  1282.7171293554916 交易位置:  11890.38 持有份额 1.5161734947665078 交易时间 2019/6/30
# 比特币加仓 总资本 17892.626130758756 剩余资金:  1211.5952928761649 交易位置:  10955.16 持有份额 1.522664282208803 交易时间 2019/7/6
# 比特币加仓 总资本 18314.206772284 剩余资金:  1138.3559842975596 交易位置:  11232.04 持有份额 1.5291835488465533 交易时间 2019/7/7
# 比特币加仓 总资本 20385.836339958365 剩余资金:  1055.5729809291322 交易位置:  12586.78 持有份额 1.5357592139553746 交易时间 2019/7/10
# 比特币加仓 总资本 19183.613305633884 剩余资金:  978.7373765259871 交易位置:  11803.97 持有份额 1.5422672142599394 交易时间 2019/7/13
# 比特币加仓 总资本 18543.757994168216 剩余资金:  904.1610360195821 交易位置:  11389.1 持有份额 1.54881395001788 交易时间 2019/7/14
# 比特币加仓 总资本 17222.065413874006 剩余资金:  843.168607720392 交易位置:  10535.75 持有份额 1.55460188464548 交易时间 2019/7/20
# 比特币加仓 总资本 17578.290068791444 剩余资金:  781.321495375023 交易位置:  10764.9 持有份额 1.5603459923841763 交易时间 2019/7/21
# 比特币加仓 总资本 16148.610754332309 剩余资金:  719.8145107772925 交易位置:  9848.65 持有份额 1.566589963452353 交易时间 2019/7/27
# 仓位转换 2019-07-28 00:00:00 719.8145107772925 0.0
# 比特币加仓 总资本 15561.660098329963 剩余资金:  659.5009740446492 交易位置:  9473.99 持有份额 1.5729549138520638 交易时间 2019/7/28
# 比特币加仓 总资本 17221.992713016192 剩余资金:  581.11440257884 交易位置:  10529.55 持有份额 1.5803978622483725 交易时间 2019/8/3
# 比特币加仓 总资本 17672.421438850783 剩余资金:  499.73381250519367 交易位置:  10814.57 持有份额 1.587921445452347 交易时间 2019/8/4
# 比特币加仓 总资本 18706.300463432195 剩余资金:  416.57442090080343 交易位置:  11465.67 持有份额 1.5951728980976594 交易时间 2019/8/7
# 比特币加仓 总资本 19329.948349843275 剩余资金:  332.2497685532581 交易位置:  11856.64 持有份额 1.6022834952642586 交易时间 2019/8/10
# 比特币加仓 总资本 18409.54849072932 剩余资金:  251.36477350324367 交易位置:  11282.22 持有份额 1.6094513063232307 交易时间 2019/8/11
# 比特币加仓 总资本 16924.363801467276 剩余资金:  175.2854952008143 交易位置:  10359.44 持有份额 1.6167937944779314 交易时间 2019/8/17
# 比特币加仓 总资本 16690.04314756204 剩余资金:  100.78455050383415 交易位置:  10214.52 持有份额 1.624085967530359 交易时间 2019/8/18
# 比特币加仓 总资本 17576.84317521963 剩余资金:  21.39841302795918 交易位置:  10760.56 持有份额 1.6314620021812685 交易时间 2019/8/21
# 比特币加仓 总资本 16998.077751118984 剩余资金:  0 交易位置:  10405.81 持有份额 1.6335179818888663 交易时间 2019/8/24
# 仓位转换 2019-08-27 00:00:00 0 0.0
# 仓位转换 2019-09-26 00:00:00 0 0.0
# 仓位转换 2019-10-26 00:00:00 0 0.0
# 仓位转换 2019-11-25 00:00:00 0 0.0
# 仓位转换 2019-12-25 00:00:00 0 0.0
# 仓位转换 2020-01-24 00:00:00 0 0.0
# 仓位转换 2020-02-23 00:00:00 0 0.0
# 售出黄金： 1.6331913436201424
# --------------------------------------------------
# M比特币 当前总资本 1.8317574236508574 卖出价格 5609.03 卖出份额 0.0003266382687239222 时间 2020/3/14
# --------------------------------------------------
# 仓位转换 2020-03-24 00:00:00 15791.029298230886 0.0
# 比特币建仓 总资本 15791.018257903526 剩余资金:  15735.816621109949 交易位置:  6741.67 持有份额 0.008188125018515919 交易时间 2020/4/4 止损价位 4299.108369007101
# 比特币加仓 总资本 15794.803998371537 剩余资金:  15672.969226245317 交易位置:  7205.55 持有份额 0.01690846252211413 交易时间 2020/4/8
# 比特币加仓 总资本 15796.281035677006 剩余资金:  15606.58304551449 交易位置:  7293.69 持有份额 0.026008507375898327 交易时间 2020/4/10
# 仓位转换 2020-04-23 00:00:00 15606.58304551449 0.0
# 比特币加仓 总资本 15801.812587622333 剩余资金:  15514.547423991246 交易位置:  7507.08 持有份额 0.03826589880900255 交易时间 2020/4/25
# 比特币加仓 总资本 15803.417914326665 剩余资金:  15421.138540342461 交易位置:  7549.52 持有份额 0.05063624892499176 交易时间 2020/4/26
# 比特币加仓 总资本 15858.046291084938 剩余资金:  15317.14327532951 交易位置:  8628.77 持有份额 0.06268599299267784 交易时间 2020/5/1
# 比特币加仓 总资本 15870.305133288295 剩余资金:  15213.537738468896 交易位置:  8824.66 持有份额 0.07442410187127876 交易时间 2020/5/2
# 比特币加仓 总资本 15881.385675785055 剩余资金:  15110.734490129005 交易位置:  8973.82 持有份额 0.08587771825778207 交易时间 2020/5/3
# 比特币加仓 总资本 15969.701917284918 剩余资金:  14997.050942029946 交易位置:  10002.48 持有份额 0.09724098176202015 交易时间 2020/5/8
# 比特币加仓 总资本 15952.110466543236 剩余资金:  14887.278207274565 交易位置:  9821.8 持有份额 0.10841518451492298 交易时间 2020/5/9
# 比特币加仓 总资本 15920.170920304423 剩余资金:  14782.098346629913 交易位置:  9527.39 持有份额 0.11945271198875126 交易时间 2020/5/10
# 比特币加仓 总资本 15893.41894266745 剩余资金:  14689.776416481725 交易位置:  9303.59 持有份额 0.12937398640586303 交易时间 2020/5/16
# 比特币加仓 总资本 15904.023368381497 剩余资金:  14597.396395488418 交易位置:  9385.7 持有份额 0.13921465345078982 交易时间 2020/5/17
# 仓位转换 2020-05-23 00:00:00 14597.396395488418 0.0
# 比特币加仓 总资本 15873.594289870594 剩余资金:  14502.229310312756 交易位置:  9167.26 持有份额 0.14959376951868258 交易时间 2020/5/23
# 比特币加仓 总资本 15875.229508860992 剩余资金:  14405.769519817899 交易位置:  9178.32 持有份额 0.16010119379615145 交易时间 2020/5/24
# 比特币加仓 总资本 15803.551249998478 剩余资金:  14312.923297812888 交易位置:  8730.73 持有份额 0.17073348416290393 交易时间 2020/5/25
# 比特币加仓 总资本 15946.687043111733 剩余资金:  14208.809040846616 交易位置:  9569.21 持有份额 0.1816114394255239 交易时间 2020/5/29
# 比特币加仓 总资本 15920.65423903321 剩余资金:  14105.800395205904 交易位置:  9425.98 持有份额 0.19253741720514 交易时间 2020/5/30
# 比特币加仓 总资本 15973.026239504923 剩余资金:  13999.371622955045 交易位置:  9698.1 持有份额 0.20350941076601375 交易时间 2020/5/31
# 比特币加仓 总资本 15937.894358416035 剩余资金:  13897.338973371436 交易位置:  9525.57 持有份额 0.21421871709982698 交易时间 2020/6/3
# 比特币加仓 总资本 15958.905473869672 剩余资金:  13792.92713905835 交易位置:  9623.75 持有份额 0.22506593945305323 交易时间 2020/6/6
# 比特币加仓 总资本 15969.39037896157 剩余资金:  13687.04115724452 交易位置:  9670.43 持有份额 0.23601320951778265 交易时间 2020/6/7
# 比特币加仓 总资本 15919.695106057474 剩余资金:  13567.353079500062 交易位置:  9459.97 持有份额 0.24866273641009556 交易时间 2020/6/13
# 比特币加仓 总资本 15923.035262326845 剩余资金:  13446.076057650474 交易位置:  9473.5 持有份额 0.2614618889192346 交易时间 2020/6/14
# 比特币加仓 总资本 15877.684154051996 剩余资金:  13312.600214332879 交易位置:  9300.15 持有份额 0.2758110288241714 交易时间 2020/6/20
# 比特币加仓 总资本 15893.454816251926 剩余资金:  13173.604765207228 交易位置:  9357.43 持有份额 0.29066207826771856 交易时间 2020/6/21
# 仓位转换 2020-06-22 00:00:00 13173.604765207228 0.0
# 比特币加仓 总资本 15970.175973573761 剩余资金:  13018.218366453799 交易位置:  9621.49 持有份额 0.3068087798376305 交易时间 2020/6/24
# 比特币加仓 总资本 15826.853055143758 剩余资金:  12863.457947372961 交易位置:  9154.45 持有份额 0.32371088462668945 交易时间 2020/6/27
# 比特币加仓 总资本 15778.194627925037 剩余资金:  12710.53671874644 交易位置:  9004.23 持有份额 0.3406907541431746 交易时间 2020/6/28
# 比特币加仓 总资本 15801.393287468694 剩余资金:  12545.28876893247 交易位置:  9072.42 持有份额 0.35890143076888226 交易时间 2020/7/4
# 比特币加仓 总资本 15822.494746857139 剩余资金:  12374.025175396077 交易位置:  9131.31 持有份额 0.3776533237247518 交易时间 2020/7/5
# 比特币加仓 总资本 15862.762403704824 剩余资金:  12177.573925709918 交易位置:  9238.04 持有份额 0.39891454009669863 交易时间 2020/7/10
# 比特币加仓 总资本 15882.412897241267 剩余资金:  11977.893183896078 交易位置:  9287.4 持有份额 0.42041041769980714 交易时间 2020/7/11
# 比特币加仓 总资本 15860.746784804134 剩余资金:  11776.85023007336 交易位置:  9235.96 持有份额 0.4421734778767745 交易时间 2020/7/12
# 比特币加仓 总资本 15824.543402770472 剩余资金:  11542.519634925704 交易位置:  9154.19 持有份额 0.4677665383660124 交易时间 2020/7/18
# 比特币加仓 总资本 15834.093612844044 剩余资金:  11300.674807157337 交易位置:  9174.71 持有份额 0.49412120990055375 交易时间 2020/7/19
# 仓位转换 2020-07-22 00:00:00 11300.674807157337 0.0
# 比特币加仓 总资本 16013.250438968504 剩余资金:  11020.641339791833 交易位置:  9537.4 持有份额 0.5234769538004771 交易时间 2020/7/23
# 比特币加仓 总资本 16020.461671269079 剩余资金:  10747.447621090418 交易位置:  9551.28 持有份额 0.5520740728131371 交易时间 2020/7/25
# 比特币加仓 总资本 16106.65194086235 剩余资金:  10473.682571042422 交易位置:  9707.5 持有份额 0.5802698294947132 交易时间 2020/7/26
# 比特币加仓 总资本 16881.1967215467 剩余资金:  10186.551615618755 交易位置:  11042.4 持有份额 0.606267215997242 交易时间 2020/7/28
# 比特币加仓 总资本 17063.936587618013 剩余资金:  9998.643003738141 交易位置:  11343.88 持有份额 0.6228286603772142 交易时间 2020/8/1
# 比特币加仓 总资本 17362.739928545045 剩余资金:  9818.213882312744 交易位置:  11823.69 持有份额 0.6380855761807268 交易时间 2020/8/2
# 比特币加仓 总资本 17223.548283126973 剩余资金:  9660.371776119593 交易位置:  11605.6 持有份额 0.6516833689776813 交易时间 2020/8/8
# 比特币加仓 总资本 17329.089009068142 剩余资金:  9500.440630222916 交易位置:  11767.6 持有份额 0.6652714554238099 交易时间 2020/8/9
# 比特币加仓 总资本 17333.565558799048 剩余资金:  9330.452955147566 交易位置:  11774.38 持有份额 0.6797056493549114 交易时间 2020/8/15
# 比特币加仓 总资本 17401.229481039398 剩余资金:  9156.616017712298 交易位置:  11873.98 持有份额 0.6943428794159245 交易时间 2020/8/16
# 比特币加仓 总资本 17467.538644118675 剩余资金:  8980.085474086081 交易位置:  11969.53 持有份额 0.7090882574363899 交易时间 2020/8/19
# 仓位转换 2020-08-21 00:00:00 8980.085474086081 0.0
# 比特币加仓 总资本 17150.73317552546 剩余资金:  8807.694259467853 交易位置:  11522.8 持有份额 0.7240461446920546 交易时间 2020/8/22
# 比特币加仓 总资本 17267.009261875024 剩余资金:  8634.227904295874 交易位置:  11683.44 持有份额 0.7388903745454377 交易时间 2020/8/23
# 比特币加仓 总资本 17157.108029980453 剩余资金:  8456.081765155594 交易位置:  11534.75 持有份额 0.7543315862784076 交易时间 2020/8/29
# 比特币加仓 总资本 17117.009505590177 剩余资金:  8276.176576161573 交易位置:  11481.64 持有份额 0.769997398405507 交易时间 2020/8/30
# 比特币加仓 总资本 17291.099520900912 剩余资金:  8090.1575563617225 交易位置:  11707.78 持有份额 0.7858827176919271 交易时间 2020/8/31
# 比特币加仓 总资本 16316.660040196586 剩余资金:  7933.336872082506 交易位置:  10467.89 持有份额 0.800860839014747 交易时间 2020/9/5
# 比特币加仓 总资本 16069.750489104921 剩余资金:  7792.4074488777815 交易位置:  10159.62 持有份额 0.8147295903023083 交易时间 2020/9/6
# 比特币加仓 总资本 16261.85518262838 剩余资金:  7668.1903022659235 交易位置:  10395.44 持有份额 0.8266763966087491 交易时间 2020/9/12
# 比特币加仓 总资本 16303.989849704321 剩余资金:  7539.018717592453 交易位置:  10446.44 持有份额 0.8390390536978978 交易时间 2020/9/13
# 比特币加仓 总资本 16721.340063901855 剩余资金:  7390.173632098739 交易位置:  10943.89 持有份额 0.8526370816778234 交易时间 2020/9/18
# 比特币加仓 总资本 16710.993185139552 剩余资金:  7240.293292025233 交易位置:  10931.79 持有份额 0.8663448431697205 交易时间 2020/9/19
# 仓位转换 2020-09-20 00:00:00 7240.293292025233 0.0
# 比特币加仓 总资本 16840.602412447006 剩余资金:  7087.1875546715455 交易位置:  11081.43 持有份额 0.8801585046131644 交易时间 2020/9/20
# 比特币加仓 总资本 16498.551818146698 剩余资金:  6938.152790304439 交易位置:  10692.84 持有份额 0.894093526868658 交易时间 2020/9/26
# 比特币加仓 总资本 16533.892513956103 剩余资金:  6789.902578598114 交易位置:  10732.4 持有份额 0.9079040974393418 交易时间 2020/9/27
# 比特币加仓 总资本 16391.01031392326 剩余资金:  6627.02330056664 交易位置:  10575.06 持有份额 0.9233032260201476 交易时间 2020/10/3
# 比特币加仓 总资本 16369.473095004567 剩余资金:  6459.555890353813 交易位置:  10551.77 持有份额 0.9391710778997981 交易时间 2020/10/4
# 比特币加仓 总资本 16849.742925338585 剩余资金:  6254.3032205511745 交易位置:  11063.19 持有份额 0.9577201245560648 交易时间 2020/10/10
# 比特币加仓 总资本 17079.055702051428 剩余资金:  6044.067602621456 交易位置:  11302.67 持有份额 0.9763169321434646 交易时间 2020/10/11
# 比特币加仓 总资本 17103.327352463246 剩余资金:  5850.822968639389 交易位置:  11327.57 持有份额 0.9933731933524892 交易时间 2020/10/17
# 比特币加仓 总资本 17141.969341403397 剩余资金:  5650.9669604674955 交易位置:  11366.51 持有份额 1.0109525598390272 交易时间 2020/10/18
# 仓位转换 2020-10-20 00:00:00 5650.9669604674955 0.0
# 比特币加仓 总资本 17706.996181629172 剩余资金:  5425.4563861268925 交易位置:  11925.46 持有份额 1.0298587891370463 交易时间 2020/10/21
# 比特币加仓 总资本 18803.534801396287 剩余资金:  5201.810075189906 交易位置:  12990.25 持有份额 1.0470718212664405 交易时间 2020/10/23
# 比特币加仓 总资本 18755.611439526663 剩余资金:  4997.931892171322 交易位置:  12944.52 持有份额 1.0628188258317297 交易时间 2020/10/24
# 比特币加仓 总资本 18951.067973754696 剩余资金:  4806.090554291872 交易位置:  13128.46 持有份额 1.0774285346082346 交易时间 2020/10/25
# 比特币加仓 总资本 19124.004576909665 剩余资金:  4637.187825313249 交易位置:  13289.0 持有份额 1.090135958431516 交易时间 2020/10/29
# 比特币加仓 总资本 19424.542043750815 剩余资金:  4463.054917752595 交易位置:  13564.72 持有份额 1.102970582953295 交易时间 2020/10/31
# 比特币加仓 总资本 19695.395790783256 剩余资金:  4283.87838516856 交易位置:  13810.32 持有份额 1.1159420929865995 交易时间 2020/11/1
# 比特币加仓 总资本 21687.8163962511 剩余资金:  4092.8179053155013 交易位置:  15595.77 持有份额 1.128190431824501 交易时间 2020/11/7
# 比特币加仓 总资本 20834.949547151704 剩余资金:  3923.50419783558 交易位置:  14839.84 持有份额 1.1395975528924924 交易时间 2020/11/8
# 比特币加仓 总资本 21391.82845154392 剩余资金:  3768.3545200259446 交易位置:  15328.53 持有份额 1.149717156930115 交易时间 2020/11/10
# 比特币加仓 总资本 22553.931470668384 剩余资金:  3612.9079344419447 交易位置:  16339.33 持有份额 1.1592288996076607 交易时间 2020/11/14
# 比特币加仓 总资本 22266.111332046126 剩余资金:  3463.017934129773 交易位置:  16091.07 持有份额 1.1685421415677362 交易时间 2020/11/15
# 比特币加仓 总资本 24122.48323670108 剩余资金:  3300.142632426175 交易位置:  17679.72 持有份额 1.1777528492688178 交易时间 2020/11/18
# 仓位转换 2020-11-19 00:00:00 3300.142632426175 0.0
# 比特币加仓 总资本 25309.30895285883 剩余资金:  3144.2982902209874 交易位置:  18687.45 持有份额 1.1860907005845016 交易时间 2020/11/21
# 比特币加仓 总资本 25323.86854351066 剩余资金:  2997.644138441852 交易位置:  18699.75 持有份额 1.1939317052403806 交易时间 2020/11/22
# 比特币加仓 总资本 23460.25984452775 剩余资金:  2874.725023039221 交易位置:  17138.87 持有份额 1.2011022209450526 交易时间 2020/11/28
# 比特币加仓 总资本 24173.14920724478 剩余资金:  2750.397537976655 交易位置:  17732.42 持有份额 1.208112128478128 交易时间 2020/11/29
# 比特币加仓 总资本 25453.844468776606 剩余资金:  2628.3437929041606 交易位置:  18792.52 持有份额 1.2146056343626317 交易时间 2020/12/2
# 比特币加仓 总资本 25305.604009016904 剩余资金:  2517.650666559196 交易位置:  18670.49 持有份额 1.220533223416081 交易时间 2020/12/5
# 比特币加仓 总资本 25897.01527812817 剩余资金:  2405.0533542624826 交易位置:  19155.06 持有份额 1.2264102500261385 交易时间 2020/12/6
# 比特币加仓 总资本 24516.42195305153 剩余资金:  2288.496936572766 交易位置:  18029.36 持有份额 1.2328737690344396 交易时间 2020/12/12
# 比特币加仓 总资本 25470.74041569394 剩余资金:  2166.1500132732085 交易位置:  18803.44 持有份额 1.239379092465035 交易时间 2020/12/13
# 比特币加仓 总资本 30482.785415154576 剩余资金:  2021.9309261536016 交易位置:  22847.46 持有份额 1.245690089357897 交易时间 2020/12/18
# 仓位转换 2020-12-19 00:00:00 2021.9309261536016 0.0
# 比特币加仓 总资本 30860.614074548586 剩余资金:  1889.3273561200308 交易位置:  23150.79 持有份额 1.2514167645436098 交易时间 2020/12/19
# 比特币加仓 总资本 31760.519968430897 剩余资金:  1762.0818924485468 交易位置:  23869.92 持有份额 1.2567464857855557 交易时间 2020/12/20
# 比特币加仓 总资本 31566.469462914905 剩余资金:  1654.982599077231 交易位置:  23715.53 持有份额 1.2612615810752565 交易时间 2020/12/25
# 比特币加仓 总资本 32800.02349077074 剩余资金:  1540.6521634466746 交易位置:  24693.58 持有份额 1.2658906212596175 交易时间 2020/12/26
# 比特币加仓 总资本 35014.83909629177 剩余资金:  1417.616794131641 交易位置:  26443.21 持有份额 1.270542506078503 交易时间 2020/12/27
# 比特币加仓 总资本 34764.9887528131 剩余资金:  1299.7406813433213 交易位置:  26246.58 持有份额 1.2750327117464362 交易时间 2020/12/28
# 比特币加仓 总资本 38253.43042370178 剩余资金:  1188.0793768538686 交易位置:  28982.56 持有份额 1.2788846481072722 交易时间 2021/1/1
# 比特币加仓 总资本 38779.27307258639 剩余资金:  1078.4095942470617 交易位置:  29393.75 持有份额 1.2826149599264922 交易时间 2021/1/2
# 比特币加仓 总资本 42372.764419302315 剩余资金:  959.3224829403557 交易位置:  32195.46 持有份额 1.2863130993115788 交易时间 2021/1/3
# 比特币加仓 总资本 48373.32805154513 剩余资金:  845.9978688456482 交易位置:  36860.41 持有份额 1.2893869108536633 交易时间 2021/1/7
# 比特币加仓 总资本 53285.66455823728 剩余资金:  739.3677742812393 交易位置:  40670.25 持有份额 1.292008207079033 交易时间 2021/1/9
# 比特币加仓 总资本 52730.68843010577 剩余资金:  640.1332070526685 交易位置:  40240.72 持有份额 1.2944737376233104 交易时间 2021/1/10
# 比特币加仓 总资本 48313.67011311236 剩余资金:  564.9708018332518 交易位置:  36828.52 持有份额 1.2965142045153895 交易时间 2021/1/16
# 比特币加仓 总资本 47324.00036930499 剩余资金:  492.35019719986644 交易位置:  36065.2 持有份额 1.298527394055908 交易时间 2021/1/17
# 仓位转换 2021-01-18 00:00:00 492.35019719986644 0.0
# 比特币加仓 总资本 43346.83124250015 剩余资金:  425.0680308091657 交易位置:  33002.38 持有份额 1.3005656928891487 交易时间 2021/1/23
# 比特币加仓 总资本 42172.875662354745 剩余资金:  360.2394879781569 交易位置:  32099.74 持有份额 1.3025848861821494 交易时间 2021/1/24
# 比特币加仓 总资本 45057.46168722859 剩余资金:  288.93885942555744 交易位置:  34314.26 持有份额 1.3046623423557153 交易时间 2021/1/30
# 比特币加仓 总资本 45062.457194404844 剩余资金:  216.94337124743487 交易位置:  34318.1 持有份额 1.30675980963857 交易时间 2021/1/31
# 比特币加仓 总资本 48569.77157762101 剩余资金:  137.53621471298294 交易位置:  37002.09 持有份额 1.3089053986655357 交易时间 2021/2/5
# 比特币加仓 总资本 50240.5990497539 剩余资金:  55.282909141869126 交易位置:  38278.61 持有份额 1.3110537749571376 交易时间 2021/2/6
# 比特币加仓 总资本 51610.180321391934 剩余资金:  0 交易位置:  39323.26 持有份额 1.3124593515744098 交易时间 2021/2/7
# 仓位转换 2021-02-17 00:00:00 0 0.0
# 仓位转换 2021-03-19 00:00:00 0 0.0
# 仓位转换 2021-04-18 00:00:00 0 0.0
# 仓位转换 2021-05-18 00:00:00 0 0.0
# 仓位转换 2021-06-17 00:00:00 0 0.0
# 仓位转换 2021-07-17 00:00:00 0 0.0
# 仓位转换 2021-08-16 00:00:00 0 0.0
# --------------------------------------------------
# M比特币 当前总资本 60844.84940659267 卖出价格 46368.69 卖出份额 1.3124593515744098 时间 2021/9/10
# --------------------------------------------------

# %% [markdown]
# ## 代码备份

# %%
Bitcoin_Data = get_unit(Bitcoin_Data.copy(), T=7, A=20, D1=20, D2=550, money=1000)
Gold_Data = get_unit(Gold_Data.copy(), T=7, A=20, D1=60, D2=120, money=1000)

# %%
close_date = positions
capital_residual = 1000  # 初始本金
fee_bit, fee_gold = 0.0002, 0.0001  # 佣金
fee_bit_sum, fee_gold_sum = 0, 0  # 总交易成本
sold_change_unit_bit = 1  # 持仓比例改变时，仓位改变份额
sold_change_unit_Gold = 1
W0, W1 = 0.8, 0.2
capital_residual_Bit = capital_residual * W0
capital_residual_Gold = capital_residual * W1
positions_Bit, positions_Gold = [], []
unit_position = [0, 0]
period = pd.date_range(start='2016/09/11', end='2021/09/10')
for i in period:
    if i not in close_date:
        # 黄金未闭市时间
        # 黄金交易
        if sold_change_unit_Gold != 0:
            price = Gold_Data.loc[i]['Value']
            capital_residual_Bit += sold_change_unit_Gold * price * (1 -
                                                                     fee_gold)
            fee_gold_sum += sold_change_unit_Gold * price * fee_gold
            sold_change_unit_Gold = 0
        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Gold_Data.loc[i]["Value Shift"] > Gold_Data.loc[i]["upper_bound"]
                and unit_position[1] == 0 and capital_residual_Gold > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Gold_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Gold_Data.loc[i]['Unit']
            if capital_buy > capital_residual_Gold:
                unit_position[1] += capital_residual_Gold / (price *
                                                             (1 + fee_bit))
                fee_gold_sum += capital_residual_Gold * fee_gold / (1 +
                                                                    fee_bit)
                capital_buy = capital_residual_Gold
                capital_residual_Gold = 0
            else:
                unit_position[1] += Gold_Data.loc[i]['Unit']
                # 剩余资金量
                capital_residual_Gold = capital_residual_Gold - capital_buy * (
                    1 + fee_gold)
                # 记录消耗费用
                fee_gold_sum += capital_buy * fee_gold
            # 总资产
            capital_all = capital_residual_Gold + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_gold = price - 2.0 * Gold_Data.loc[i]['VAR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Gold_Data.loc[i]["ATR"]
            positions_Gold += [{
                "Date": Gold_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[1]
            }]
            print('黄金建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Gold,
                  "交易位置: ", price, "持有份额", unit_position[1], "交易时间",
                  Gold_Data.loc[i]['Date'], "止损价位", stop_loss_gold)
        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[1] > 0 and capital_residual_Gold > 0 and (
                Gold_Data.loc[i]["Value Shift"] > positions_Gold[-1]['Price'] +
                0.5 * Gold_Data.loc[i]["ATR"]) and (
                    i != pd.to_datetime('2021/09/10')):
            if unit_position[1] > 4 or capital_residual_Gold <= 0:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Gold_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Gold_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_gold)) <= capital_residual_Gold:
                    unit_position[1] += Gold_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Gold -= capital_buy * (1 + fee_gold)
                    # 记录消耗费用
                    fee_gold_sum += capital_buy * fee_gold
                # 若不充足
                elif (capital_buy * (1 + fee_gold)) > capital_residual_Gold:
                    # 剩下的钱全部购买
                    unit_position[1] += capital_residual_Gold / (
                        price * (1 + fee_gold))
                    # 记录消耗费用
                    fee_gold_sum += capital_buy * fee_gold
                    capital_residual_Gold = 0
                capital_all = capital_residual_Gold + unit_position[1] * price
                positions_Gold += [{
                    "Date": Gold_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[1]
                }]
                # stop_loss_gold = price - (2.0 - 0.5) * Gold_Data.loc[i]["ATR"]
            print('黄金加仓', "总资本", capital_all, "剩余资金: ", capital_residual_Gold,
                  "交易位置: ", price, "持有份额", unit_position[1], "交易时间",
                  Gold_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[1] > 0 and (
                Gold_Data.loc[i]["Value Shift"] <
                Gold_Data.loc[i]["lower_bound"]
                or Gold_Data.loc[i]["Value Shift"] < stop_loss_gold
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Gold_Data.loc[i]['Value']
            capital_sell = unit_position[1] * price * (1 - fee_gold)
            fee_gold_sum += unit_position[1] * price * fee_gold
            capital_residual_Gold = capital_sell + capital_residual_Gold
            capital_all = capital_residual_Gold
            all = unit_position[0]*Bitcoin_Data.loc[i]['Value']+unit_position[1]*Gold_Data.loc[i]['Value']+capital_residual_Bit+capital_residual_Gold
            print('-' * 50)
            print('M黄金', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[1], "时间", Gold_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_gold, unit_position[1] = 0.0, 0.0

        ###############################################
        ###############################################
        # 比特币交易
        if sold_change_unit_bit != 0:
            price = Bitcoin_Data.loc[i]['Value']
            capital_residual_Gold += sold_change_unit_bit * price * (1 -
                                                                     fee_bit)
            fee_bit_sum += sold_change_unit_bit * price * fee_bit
            sold_change_unit_bit = 0

        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Bitcoin_Data.loc[i]["Value Shift"] >
                Bitcoin_Data.loc[i]["upper_bound"] and unit_position[0] == 0
                and capital_residual_Bit > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Bitcoin_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Bitcoin_Data.loc[i]['Unit']
            unit_position[0] += Bitcoin_Data.loc[i]['Unit']
            # 剩余资金量
            capital_residual_Bit = capital_residual_Bit - capital_buy * (
                1 + fee_bit)
            # 记录消耗费用
            fee_bit_sum += capital_buy * fee_bit
            # 总资产
            capital_all = capital_residual_Bit + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_bit = price - 2.0 * Bitcoin_Data.loc[i]['ATR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Bitcoin_Data.loc[i]["ATR"]
            positions_Bit += [{
                "Date": Bitcoin_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[0]
            }]
            print('比特币建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'], "止损价位", stop_loss_bit)

        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[0] > 0 and capital_residual_Bit > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] >
                positions_Bit[-1]['Price'] + 0.5 * Bitcoin_Data.loc[i]["ATR"]
        ) and (i != pd.to_datetime('2021/09/10')):
            if unit_position[0] > 4:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Bitcoin_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Bitcoin_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_bit)) <= capital_residual_Bit:
                    unit_position[0] += Bitcoin_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Bit -= capital_buy * (1 + fee_bit)
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                # 若不充足
                elif (capital_buy * (1 + fee_bit)) > capital_residual_Bit:
                    # 剩下的钱全部购买
                    unit_position[0] += capital_residual_Bit / (price *
                                                                (1 + fee_bit))
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                    capital_residual_Bit = 0
                capital_all = capital_residual_Bit + unit_position[0] * price
                positions_Bit += [{
                    "Date": Bitcoin_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[0]
                }]
                # stop_loss = price - (2.0 - 0.5) * Bitcoin_Data.loc[i]["ATR"]
            print("比特币加仓", "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[0] > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] <
                Bitcoin_Data.loc[i]["lower_bound"]
                or Bitcoin_Data.loc[i]["Value Shift"] < stop_loss_bit
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Bitcoin_Data.loc[i]['Value']
            capital_sell = unit_position[0] * price * (1 - fee_bit)
            fee_bit_sum += unit_position[0] * price * fee_bit
            capital_residual_Bit = capital_sell + capital_residual_Bit
            capital_all = capital_residual_Bit
            print('-' * 50)
            print('M比特币', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[0], "时间", Bitcoin_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_bit, unit_position[0] = 0.0, 0.0
    ###############################################
    ###############################################
    else:
        # 黄金闭市时间
        # 仅交易比特币
        if sold_change_unit_bit != 0:
            price = Bitcoin_Data.loc[i]['Value']
            capital_residual_Gold += sold_change_unit_bit * price * (1 -
                                                                     fee_bit)
            fee_bit_sum += sold_change_unit_bit * price * fee_bit
            sold_change_unit_bit = 0

        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
        if (Bitcoin_Data.loc[i]["Value Shift"] >
                Bitcoin_Data.loc[i]["upper_bound"] and unit_position[0] == 0
                and capital_residual_Bit > 0
                and i != pd.to_datetime('2021/09/10')):
            # 使用当前价格
            price = Bitcoin_Data.loc[i]['Value']
            # 消耗资金量=使用当前价格*一个单位*（1+fees)
            capital_buy = price * Bitcoin_Data.loc[i]['Unit']
            unit_position[0] += Bitcoin_Data.loc[i]['Unit']
            # 剩余资金量
            capital_residual_Bit = capital_residual_Bit - capital_buy * (
                1 + fee_bit)
            # 记录消耗费用
            fee_bit_sum += capital_buy * fee_bit
            # 总资产
            capital_all = capital_residual_Bit + capital_buy
            # 不考虑期货空头，第一次加仓时，止损位置在2N处
            # 止损使用VAR替换ATR
            stop_loss_bit = price - 2.0 * Bitcoin_Data.loc[i]['ATR']
            # 加仓位置在0.5N处
            begin_chance = price + 0.5 * Bitcoin_Data.loc[i]["ATR"]
            positions_Bit += [{
                "Date": Bitcoin_Data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position[0]
            }]
            print('比特币建仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'], "止损价位", stop_loss_bit)

        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
        if unit_position[0] > 0 and capital_residual_Bit > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] >
                positions_Bit[-1]['Price'] + 0.5 * Bitcoin_Data.loc[i]["ATR"]
        ) and (i != pd.to_datetime('2021/09/10')):
            if unit_position[0] > 8 or capital_residual_Bit <= 0:
                # 如果此时仓位达到4unit，或没有子弹，不再加仓
                pass
            else:
                # 使用当前价格
                price = Bitcoin_Data.loc[i]['Value']
                # 购买资金量=使用当前价格*一个单位
                capital_buy = price * Bitcoin_Data.loc[i]['Unit']
                # 如果剩余资金量充足
                if (capital_buy * (1 + fee_bit)) <= capital_residual_Bit:
                    unit_position[0] += Bitcoin_Data.loc[i]['Unit']
                    # 剩余资金量
                    capital_residual_Bit -= capital_buy * (1 + fee_bit)
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                # 若不充足
                elif (capital_buy * (1 + fee_bit)) > capital_residual_Bit:
                    # 剩下的钱全部购买
                    unit_position[0] += capital_residual_Bit / (price *
                                                                (1 + fee_bit))
                    # 记录消耗费用
                    fee_bit_sum += capital_buy * fee_bit
                    capital_residual_Bit = 0
                capital_all = capital_residual_Bit + unit_position[0] * price
                positions_Bit += [{
                    "Date": Bitcoin_Data.loc[i]['Date'],
                    "Price": price,
                    "Unit": unit_position[0]
                }]
                # stop_loss_bit = price - (2.0 - 0.5) * Bitcoin_Data.loc[i]["ATR"]
            print('比特币加仓', "总资本", capital_all, "剩余资金: ", capital_residual_Bit,
                  "交易位置: ", price, "持有份额", unit_position[0], "交易时间",
                  Bitcoin_Data.loc[i]['Date'])

        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
        if unit_position[0] > 0 and (
                Bitcoin_Data.loc[i]["Value Shift"] <
                Bitcoin_Data.loc[i]["lower_bound"]
                or Bitcoin_Data.loc[i]["Value Shift"] < stop_loss_bit
                or i == pd.to_datetime('2021/09/10')):
            # 使用当前价格全部卖出
            price = Bitcoin_Data.loc[i]['Value']
            capital_sell = unit_position[0] * price * (1 - fee_bit)
            fee_bit_sum += unit_position[0] * price * fee_bit
            capital_residual_Bit += capital_sell
            capital_all = capital_residual_Bit
            print('-' * 50)
            print('M比特币', "当前总资本", capital_all, "卖出价格", price, '卖出份额',
                  unit_position[0], "时间", Bitcoin_Data.loc[i]['Date'])
            # 止损位和持仓归零
            print('-' * 50)
            stop_loss_bit, unit_position[0] = 0.0, 0.0
    all = unit_position[0]*Bitcoin_Data.loc[i]['Value']+unit_position[1]*Gold_Data.loc[i]['Value']+capital_residual_Bit+capital_residual_Gold
# Out:
# 比特币建仓 总资本 2124.3626713544863 剩余资金:  1600.0194437871044 交易位置:  614.74 持有份额 0.8529512111907178 交易时间 2016/10/8 止损价位 591.2919999999999
# 比特币加仓 总资本 2142.3564469522394 剩余资金:  1070.6680761134821 交易位置:  635.96 持有份额 1.6851505925510366 交易时间 2016/10/13
# 比特币加仓 总资本 2171.4048206525827 剩余资金:  631.1799717475499 交易位置:  653.25 持有份额 2.357787751863808 交易时间 2016/10/23
# 比特币加仓 总资本 2252.5107231043853 剩余资金:  267.4580175636144 交易位置:  687.68 持有份额 2.8865936271823687 交易时间 2016/10/28
# 比特币加仓 总资本 2279.389160738666 剩余资金:  0 交易位置:  697.01 持有份额 3.270238821162775 交易时间 2016/11/1
# 黄金建仓 总资本 821.4729680594987 剩余资金:  294.4535630464991 交易位置:  1214.75 持有份额 0.4338500967384233 交易时间 2017/1/18 止损价位 -1086.23
# 黄金加仓 总资本 833.3093257932312 剩余资金:  0 交易位置:  1242.1 持有份额 0.670887469441455 交易时间 2017/2/8
# --------------------------------------------------
# M黄金 当前总资本 838.9615091155902 卖出价格 1250.65 卖出份额 0.670887469441455 时间 2017/12/8
# --------------------------------------------------
# 黄金建仓 总资本 838.8938751673882 剩余资金:  162.55439314721968 交易位置:  1314.5 持有份额 0.5145222381286941 交易时间 2018/1/4 止损价位 -1206.6499999999996
# 黄金加仓 总资本 845.2062448824378 剩余资金:  0 交易位置:  1326.8 持有份额 0.637026111608711 交易时间 2018/1/12
# --------------------------------------------------
# M黄金 当前总资本 830.7263738146049 卖出价格 1304.2 卖出份额 0.637026111608711 时间 2018/5/2
# --------------------------------------------------
# 黄金建仓 总资本 830.6708599767212 剩余资金:  275.5324811399838 交易位置:  1229.05 持有份额 0.4516808745264533 交易时间 2018/10/17 止损价位 -1144.5700000000004
# 黄金加仓 总资本 833.7373234741628 剩余资金:  0 交易位置:  1235.9 持有份额 0.674599339326938 交易时间 2018/12/5
# --------------------------------------------------
# M黄金 当前总资本 1221.0376080772182 卖出价格 1810.2 卖出份额 0.674599339326938 时间 2020/11/25
# --------------------------------------------------
# 黄金建仓 总资本 1220.9805197113344 剩余资金:  650.0968608725223 交易位置:  1836.55 持有份额 0.31084569374033494 交易时间 2021/5/7 止损价位 -1697.7500000000002
# 黄金加仓 总资本 1237.0602470914655 剩余资金:  118.40244682484695 交易位置:  1888.45 持有份额 0.5923682386436594 交易时间 2021/5/19
# --------------------------------------------------
# M黄金 当前总资本 1151.1524223978415 卖出价格 1743.6 卖出份额 0.5923682386436594 时间 2021/8/11
# --------------------------------------------------
# --------------------------------------------------
# M比特币 当前总资本 151606.36278643727 卖出价格 46368.69 卖出份额 3.270238821162775 时间 2021/9/10
# --------------------------------------------------

# %%
def reverse(i,
            data,
            unit_position,
            capital_residual,
            fee,
            fee_sum,
            sold_change_unit,
            capital_residual_other,
            positions,
            kind=0):
    if sold_change_unit != 0:
        price = data.loc[i]['Value']
        capital_residual_other += sold_change_unit * price * (1 - fee)
        fee_sum += sold_change_unit * price * fee
        sold_change_unit = 0

        # 前一天的收盘价超过高价突破位，且未进场交易;
        # 不考虑做空，进场仅买入;
        # 首次建仓为1个单位(unit)
    if (data.loc[i]["Value Shift"] > data.loc[i]["upper_bound"]
            and unit_position == 0 and capital_residual > 0
            and i != pd.to_datetime('2021/09/10')):
        # 使用当前价格
        price = data.loc[i]['Value']
        # 消耗资金量=使用当前价格*一个单位*（1+fees)
        capital_buy = price * data.loc[i]['Unit']
        unit_position += data.loc[i]['Unit']
        # 剩余资金量
        capital_residual = capital_residual - capital_buy * (1 + fee)
        # 记录消耗费用
        fee_sum += capital_buy * fee
        # 总资产
        capital_all = capital_residual + capital_buy
        # 不考虑期货空头，第一次加仓时，止损位置在2N处
        # 止损使用VAR替换ATR
        stop_loss = price - 2.0 * data.loc[i]['VAR']
        # 加仓位置在0.5N处
        begin_chance = price + 0.5 * data.loc[i]["ATR"]
        positions += [{
            "Date": data.loc[i]['Date'],
            "Price": price,
            "Unit": unit_position
        }]
        if kind == 0:
            print('比特币建仓')
        elif kind == 1:
            print("黄金建仓")
        print("总资本", capital_all, "剩余资金: ", capital_residual, "交易位置: ", price,
              "持有份额", unit_position, "交易时间", data.loc[i]['Date'], "止损价位",
              stop_loss)

        # 进场交易以后，仓位大于0，当价格高于上一次交易+0.5*ATR时，加仓。
        # 且满足回测尚未结束
    if unit_position > 0 and (
            data.loc[i]["Value Shift"] > positions[-1]['Price'] +
            0.5 * data.loc[i]["ATR"]) and (i != pd.to_datetime('2021/09/10')):
        if unit_position > 4 or capital_residual <= 0:
            # 如果此时仓位达到4unit，或没有子弹，不再加仓
            pass
        else:
            # 使用当前价格
            price = data.loc[i]['Value']
            # 购买资金量=使用当前价格*一个单位
            capital_buy = price * data.loc[i]['Unit']
            # 如果剩余资金量充足
            if (capital_buy * (1 + fee)) <= capital_residual:
                unit_position += data.loc[i]['Unit']
                # 剩余资金量
                capital_residual -= capital_buy * (1 + fee)
                # 记录消耗费用
                fee_sum += capital_buy * fee
            # 若不充足
            elif (capital_buy * (1 + fee)) > capital_residual:
                # 剩下的钱全部购买
                unit_position += capital_residual / (price * (1 + fee))
                # 记录消耗费用
                fee_sum += capital_buy * fee
                capital_residual = 0

            capital_all = capital_residual + unit_position * price
            positions += [{
                "Date": data.loc[i]['Date'],
                "Price": price,
                "Unit": unit_position
            }]
            # stop_loss = price - (2.0 - 0.5) * data.loc[i]["ATR"]
        if kind == 0:
            print('比特币加仓')
        elif kind == 1:
            print("黄金加仓")
            print("总资本", capital_all, "剩余资金: ", capital_residual, "交易位置: ",
                  price, "持有份额", unit_position, "交易时间", data.loc[i]['Date'])
        # 进场交易以后, 仓位大于0，当价格低于低价突破位，或低于止损价位时，清仓止损
        # 或回测结束时，清仓;
    if unit_position > 0 and (
            data.loc[i]["Value Shift"] < data.loc[i]["lower_bound"]
            or data.loc[i]["Value Shift"] < stop_loss
            or i != pd.to_datetime('2021/09/10')):
        # 使用当前价格全部卖出
        price = data.loc[i]['Value']
        capital_sell = unit_position * price * (1 - fee)
        fee_sum += unit_position * price * fee
        capital_residual = capital_sell + capital_residual
        capital_all = capital_residual
        print('-' * 50)
        if kind == 0:
            print('比特币卖出')
        elif kind == 1:
            print("黄金卖出")
        print('M', "当前总资本", capital_all, "卖出价格", price, '卖出份额', unit_position,
              "时间", data.loc[i]['Date'])
        # 止损位和持仓归零
        print('-' * 50)
        stop_loss, unit_position = 0.0, 0.0

    return unit_position, capital_residual, fee_sum, sold_change_unit, capital_residual_other, positions

# %%
close_date = positions
capital_residual = 1000  # 初始本金
fee_bit, fee_gold = 0.0002, 0.0001  # 佣金
fee_bit_sum, fee_gold_sum = 0, 0  # 总交易成本
sold_change_unit_bit = 1  # 持仓比例改变时，仓位改变份额
sold_change_unit_Gold = 1
W0, W1 = 0.5, 0.5
capital_residual_Bit = capital_residual * W0
capital_residual_Gold = capital_residual * W1
positions_Bit, positions_Gold = [], []
unit_position = [0, 0]
period = pd.date_range(start='2016/09/11', end='2021/09/10')


for i in period:
    if i in weight_data['Date']:
        # 达到时间点，更改权重
        weight_change = weight_data.loc[i]
        W0, W1 = weight_change['W0'], 1 - weight_change['W0']
        # 计算当天持有份额的价值
        capital_hold_Bit = unit_position[0] * Bitcoin_Data.loc[i]['Value']
        capital_hold_Gold = unit_position[1] * Gold_Data.loc[i]['Value']
        # 计算总资本价值
        capital_all = capital_hold_Bit + capital_residual_Bit + capital_hold_Gold + capital_residual_Gold
        # 按比列分配资产组合, 计算需要调整的资本
        capital_change_Bit, capital_change_Gold = capital_all * W0, capital_all * W1
        share_adj_Bit = capital_change_Bit - (capital_hold_Bit +
                                              capital_residual_Bit)
        # 判断是否需要调整资产持有份额
        if share_adj_Bit > 0:
            # 比特币资产比例提高时，黄金资产需要降低份额
            # 判断黄金资产账户，是否剩余足够的资金
            if capital_residual_Gold - share_adj_Bit >= 0:
                # 如果剩余资金足够，划入对应资金比特币账户
                capital_residual_Gold -= share_adj_Bit
                # 比特币账户增持
                capital_residual_Bit += share_adj_Bit
            elif capital_residual_Gold - share_adj_Bit < 0:
                # 黄金资产账户剩余资金不足时，判断如何售出
                if capital_residual_Gold == 0:
                    # 如果黄金账户没有钱，则在下次开市时卖出当前价格对应价值的份额
                    sold_change_unit_Gold = share_adj_Bit / (unit_position[1] *
                                                             (1 + fee_gold))
                    # 总仓位同时降低
                    unit_position[1] -= sold_change_unit_Gold
                elif capital_residual_Gold > 0:
                    # 剩下的钱先划走，不够的卖份额
                    capital_residual_Gold = 0
                    sold_change_unit_Gold = (share_adj_Bit -
                                             capital_residual_Gold) / (
                                                 unit_position[1] *
                                                 (1 + fee_gold))
                    # 总仓位同时降低
                    unit_position[1] -= sold_change_unit_Gold
        elif share_adj_Bit < 0:
            # 黄金资产提高时，比特币资产需要降低份额
            # 判断比特币资产账户，是否剩余足够的资金
            if capital_residual_Bit - np.abs(share_adj_Bit) >= 0:
                # 如果剩余资金足够，划入对应资金黄金账户
                capital_residual_Bit -= np.abs(share_adj_Bit)
                # 黄金账户增持
                capital_residual_Gold += np.abs(share_adj_Bit)
            elif capital_residual_Bit - np.abs(share_adj_Bit) < 0:
                # 比特币资产账户剩余资金不足时，判断如何售出
                if capital_residual_Bit == 0:
                    # 如果黄金账户没有钱，则在下次开市时卖出当前价格对应价值的份额
                    sold_change_unit_bit = np.abs(share_adj_Bit) / (unit_position[0] *
                                                            (1 + fee_bit))
                    # 总仓位同时降低
                    unit_position[0] -= sold_change_unit_bit
                elif capital_residual_Bit > 0:
                    # 剩下的钱先划走，不够的卖份额
                    capital_residual_Bit = 0
                    sold_change_unit_bit = (np.abs(share_adj_Bit) -
                                            capital_residual_Bit) / (
                                                unit_position[0] *
                                                (1 + fee_bit))
                    # 总仓位同时降低
                    unit_position[0] -= sold_change_unit_bit
    if i not in close_date:
        # 黄金未闭市时间
        # 黄金交易
        unit_position[
            1], capital_residual_Gold, fee_gold_sum, sold_change_unit_Gold, capital_residual_Bit, positions_Bit = reverse(
                i,
                data=Gold_Data,
                unit_position=unit_position[1],
                capital_residual=capital_residual_Gold,
                fee=fee_gold,
                fee_sum=fee_gold_sum,
                sold_change_unit=sold_change_unit_Gold,
                capital_residual_other=capital_residual_Bit,
                positions=positions_Gold,
                kind=1)
        # 比特币交易
        unit_position[
            0], capital_residual_Bit, fee_bit_sum, sold_change_unit_bit, capital_residual_Gold, positions_Bit = reverse(
                i,
                Bitcoin_Data,
                unit_position[0],
                capital_residual_Bit,
                fee_bit,
                fee_bit_sum,
                sold_change_unit_bit,
                capital_residual_Gold,
                positions_Bit,
                kind=0)

    elif i in close_date:
        # 黄金闭市时间
        # 仅交易比特币
        unit_position[
            0], capital_residual_Bit, fee_bit_sum, sold_change_unit_bit, capital_residual_Gold, positions_Bit = reverse(
                i,
                Bitcoin_Data,
                unit_position[0],
                capital_residual_Bit,
                fee_bit,
                fee_bit_sum,
                sold_change_unit_bit,
                capital_residual_Gold,
                positions_Bit,
                kind=0)
# Out:
# 黄金建仓
# 总资本 2945.946020248087 剩余资金:  2474.0485011179157 交易位置:  1242.1 持有份额 0.3799191040416802 交易时间 2017/2/8 止损价位 -1136.33
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.8988304961736 卖出价格 1242.1 卖出份额 0.3799191040416802 时间 2017/2/8
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.851893690544 剩余资金:  2476.483837392147 交易位置:  1236.8 持有份额 0.37950198601099344 交易时间 2017/2/9 止损价位 -1141.6299999999999
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.8049568849137 卖出价格 1236.8 卖出份额 0.37950198601099344 时间 2017/2/9
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.74714092133 剩余资金:  2367.5875050818963 交易位置:  1253.65 持有份额 0.4611810599764157 交易时间 2017/2/24 止损价位 -1190.85
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.689324957746 卖出价格 1253.65 卖出份额 0.4611810599764157 时间 2017/2/24
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.626765718974 剩余资金:  2320.034378001348 交易位置:  1245.8 持有份额 0.50216117171105 交易时间 2017/4/5 止损价位 -1218.4400000000003
# 黄金加仓
# 总资本 2945.5642064802023 剩余资金:  1694.3794310449503 交易位置:  1245.8 持有份额 1.0043223434221 交易时间 2017/4/5
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.439088002659 卖出价格 1245.8 卖出份额 1.0043223434221 时间 2017/4/5
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.374163252872 剩余资金:  2296.1266653849957 交易位置:  1284.15 持有份额 0.5055854050289114 交易时间 2017/4/13 止损价位 -1207.2599999999998
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.3092385030855 卖出价格 1284.15 卖出份额 0.5055854050289114 时间 2017/4/13
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.2315012375384 剩余资金:  2167.8588457643327 交易位置:  1291.0 持有份额 0.602147680459493 交易时间 2017/6/7 止损价位 -1213.9900000000002
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2945.153763971991 卖出价格 1291.0 卖出份额 0.602147680459493 时间 2017/6/7
# --------------------------------------------------
# 比特币建仓
# 总资本 2945.1351863909763 剩余资金:  2852.247281318707 交易位置:  3252.562533 持有份额 0.028558376397023265 交易时间 2017/8/6 止损价位 -1277.7686070000004
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2945.1166088099617 卖出价格 3252.562533 卖出份额 0.028558376397023265 时间 2017/8/6
# --------------------------------------------------
# 黄金建仓
# 总资本 2945.037122645239 剩余资金:  2150.1754754151925 交易位置:  1284.4 持有份额 0.6188583363672113 交易时间 2017/8/10 止损价位 -1223.1399999999999
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2944.9576364805157 卖出价格 1284.4 卖出份额 0.6188583363672113 时间 2017/8/10
# --------------------------------------------------
# 黄金建仓
# 总资本 2944.880559185327 剩余资金:  2174.1076072965043 交易位置:  1286.1 持有份额 0.5993102806071244 交易时间 2017/8/11 止损价位 -1221.44
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2944.803481890138 卖出价格 1286.1 卖出份额 0.5993102806071244 时间 2017/8/11
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.378829279391 剩余资金:  1357.8205008907546 交易位置:  7365.99 持有份额 0.015552332868852194 交易时间 2017/11/5 止损价位 -3839.6252920000024
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.3559176137135 卖出价格 7365.99 卖出份额 0.015552332868852194 时间 2017/11/5
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.3384627690664 剩余资金:  1385.0642395336638 交易位置:  7868.77 持有份额 0.011091215429527445 交易时间 2017/11/17 止损价位 -4320.172316600001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.3210079244193 卖出价格 7868.77 卖出份额 0.011091215429527445 时间 2017/11/17
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.3047924341013 剩余资金:  1391.2273408448607 交易位置:  7817.140383 持有份额 0.010371753303236112 交易时间 2017/11/18 止损价位 -4371.801933600002
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.2885769437835 卖出价格 7817.140383 卖出份额 0.010371753303236112 时间 2017/11/18
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.273216279126 剩余资金:  1395.4698929927465 交易位置:  8049.72 持有份额 0.00954111736636549 交易时间 2017/11/20 止损价位 -4782.0743166
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.2578556144688 卖出价格 8049.72 卖出份额 0.00954111736636549 时间 2017/11/20
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.2428396154417 剩余资金:  1397.1628444790576 交易位置:  8059.8 持有份额 0.009315367023546977 交易时间 2017/11/21 止损价位 -4771.9943166
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.2278236164143 卖出价格 8059.8 卖出份额 0.009315367023546977 时间 2017/11/21
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.212190200493 剩余资金:  1394.0451105950067 交易位置:  8268.035 持有份额 0.009454130226285502 交易时间 2017/11/22 止损价位 -4563.759316600001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.196556784572 卖出价格 8268.035 卖出份额 0.009454130226285502 时间 2017/11/22
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.1805242713715 剩余资金:  1392.0179582691117 交易位置:  8236.72 持有份额 0.00973234078641254 交易时间 2017/11/23 止损价位 -4595.074316600001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.1644917581712 卖出价格 8236.72 卖出份额 0.00973234078641254 时间 2017/11/23
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.1461796729627 剩余资金:  1380.585753630468 交易位置:  8768.8 持有份额 0.010441614136768407 交易时间 2017/11/26 止损价位 -4062.994316600001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.1278675877543 卖出价格 8768.8 卖出份额 0.010441614136768407 时间 2017/11/26
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.1073166218937 剩余资金:  1369.3524873182664 交易位置:  9718.29505 持有份额 0.010573339127383993 交易时间 2017/11/27 止损价位 -3113.4992666
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.0867656560329 卖出价格 9718.29505 卖出份额 0.010573339127383993 时间 2017/11/27
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.0664836159408 剩余资金:  1370.6562831551264 交易位置:  9952.50882 持有份额 0.01018941076013177 交易时间 2017/11/28 止损价位 -2879.2854966000014
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.0462015758485 卖出价格 9952.50882 卖出份额 0.01018941076013177 时间 2017/11/28
# --------------------------------------------------
# 比特币建仓
# 总资本 1472.0267168324788 剩余资金:  1374.6029999844918 交易位置:  9919.0 持有份额 0.009821929312227744 交易时间 2017/11/29 止损价位 -2912.7943166000005
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1472.0072320891093 卖出价格 9919.0 卖出份额 0.009821929312227744 时间 2017/11/29
# --------------------------------------------------
# 比特币建仓
# 总资本 1471.9873560994768 剩余资金:  1372.6074079364278 交易位置:  10883.912 持有份额 0.009130903315191171 交易时间 2017/12/1 止损价位 -1947.8823166000002
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1471.967480109844 卖出价格 10883.912 卖出份额 0.009130903315191171 时间 2017/12/1
# --------------------------------------------------
# 比特币建仓
# 总资本 1471.9485461988925 剩余资金:  1377.2789914419955 交易位置:  10879.88 持有份额 0.008701341812308328 交易时间 2017/12/2 止损价位 -2209.2555594000023
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1471.9296122879412 卖出价格 10879.88 卖出份额 0.008701341812308328 时间 2017/12/2
# --------------------------------------------------
# 比特币建仓
# 总资本 1471.9105955197008 剩余资金:  1376.8267543186312 交易位置:  11584.83 持有份额 0.008207616443320248 交易时间 2017/12/4 止损价位 -3942.511244000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 1471.8915787514607 卖出价格 11584.83 卖出份额 0.008207616443320248 时间 2017/12/4
# --------------------------------------------------
# 比特币建仓
# 总资本 2944.2695238955607 剩余资金:  2825.2905190528804 交易位置:  7715.1 持有份额 0.015421576498383742 交易时间 2018/7/24 止损价位 -4772.943499999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2944.2457280945923 卖出价格 7715.1 卖出份额 0.015421576498383742 时间 2018/7/24
# --------------------------------------------------
# 比特币建仓
# 总资本 2944.2197685460515 剩余资金:  2814.4220258417326 交易位置:  8251.165 持有份额 0.015730838336685662 交易时间 2018/7/25 止损价位 -4236.878499999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2944.1938089975106 卖出价格 8251.165 卖出份额 0.015730838336685662 时间 2018/7/25
# --------------------------------------------------
# 比特币建仓
# 总资本 2944.1686062997524 剩余资金:  2818.155117507204 交易位置:  8187.324167 持有份额 0.015391291003287835 交易时间 2018/7/26 止损价位 -4300.719333
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2944.1434036019937 卖出价格 8187.324167 卖出份额 0.015391291003287835 时间 2018/7/26
# --------------------------------------------------
# 比特币建仓
# 总资本 2944.1126154805957 剩余资金:  2790.1720084888093 交易位置:  3766.89 持有份额 0.04086676462327973 交易时间 2019/2/25 止损价位 -3042.3220000000006
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2944.0202511164007 卖出价格 3766.89 卖出份额 0.08173352924655947 时间 2019/2/25
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.981262472119 剩余资金:  2749.0380410636985 交易位置:  5771.08 持有份额 0.033779330975904055 交易时间 2019/5/5 止损价位 -4588.253999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.942273827837 卖出价格 5771.08 卖出份额 0.033779330975904055 时间 2019/5/5
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.904995912252 剩余资金:  2757.515417986252 交易位置:  5717.66 持有份额 0.032598926470968896 交易时间 2019/5/6 止损价位 -4675.431999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.8677179966667 卖出价格 5717.66 卖出份额 0.032598926470968896 时间 2019/5/6
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.8318546734386 剩余资金:  2764.5152385311685 交易位置:  6146.91 持有份额 0.029171830422483808 交易时间 2019/5/10 止损价位 -4361.382
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.79599135021 卖出价格 6146.91 卖出份额 0.029171830422483808 时间 2019/5/10
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.759731985463 剩余资金:  2762.4629082513547 交易位置:  6348.02 持有份额 0.028559586096784256 交易时间 2019/5/11 止损价位 -4160.271999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.723472620716 卖出价格 6348.02 卖出份额 0.028559586096784256 时间 2019/5/11
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.6838443791703 剩余资金:  2745.5426366485644 交易位置:  7248.31 持有份额 0.027336193917010424 交易时间 2019/5/12 止损价位 -3259.981999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.644216137624 卖出价格 7248.31 卖出份额 0.027336193917010424 时间 2019/5/12
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.6114308061897 剩余资金:  2779.684773636458 交易位置:  6978.63 持有份额 0.02348980490006375 交易时间 2019/5/13 止损价位 -3529.6619999999994
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.5130748118877 卖出价格 6978.63 卖出份额 0.0469796098001275 时间 2019/5/13
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.4846240453744 剩余资金:  2801.2307914785597 交易位置:  7992.69 持有份额 0.017797991986029046 交易时间 2019/5/15 止损价位 -2515.602
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.4561732788607 卖出价格 7992.69 卖出份额 0.017797991986029046 时间 2019/5/15
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.4303883876482 剩余资金:  2814.5059323249966 交易位置:  8206.9 持有份额 0.015709275860879467 交易时间 2019/5/16 止损价位 -2330.851999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.404603496436 卖出价格 8206.9 卖出份额 0.015709275860879467 时间 2019/5/16
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.3823185187166 剩余资金:  2831.957429921964 交易位置:  7885.96 持有份额 0.014129527488949042 交易时间 2019/5/17 止损价位 -2651.7919999999986
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.3600335409974 卖出价格 7885.96 卖出份额 0.014129527488949042 时间 2019/5/17
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.339252163512 剩余资金:  2839.4323647351903 交易位置:  8770.06 持有份额 0.01184791066746653 交易时间 2019/5/28 止损价位 -3481.7219999999998
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.318470786026 卖出价格 8770.06 卖出份额 0.01184791066746653 时间 2019/5/28
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.29816923016 剩余资金:  2841.7903898993554 交易位置:  8719.88 持有份额 0.011640960578678214 交易时间 2019/5/29 止损价位 -3935.938000000002
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.2778676742937 卖出价格 8719.88 卖出份额 0.011640960578678214 时间 2019/5/29
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.255881909803 剩余资金:  2833.327059457047 交易位置:  8978.99 持有份额 0.012242893961654495 交易时间 2019/6/17 止损价位 -6365.572
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.233896145313 卖出价格 8978.99 卖出份额 0.012242893961654495 时间 2019/6/17
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.211394014637 剩余资金:  2830.700740635075 交易位置:  9327.48 持有份额 0.012062277633354575 交易时间 2019/6/18 止损价位 -6017.082
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.1888918839613 卖出价格 9327.48 卖出份额 0.012062277633354575 时间 2019/6/18
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.167737118801 剩余资金:  2837.3939113166 交易位置:  9076.18 持有份额 0.011654002653341025 交易时间 2019/6/19 止损价位 -6268.382
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.1465823536405 卖出价格 9076.18 卖出份额 0.011654002653341025 时间 2019/6/19
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.1234168123974 剩余资金:  2827.2957105982387 交易位置:  10209.38 持有份额 0.011345224314714394 交易时间 2019/6/22 止损价位 -5135.182000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.100251271155 卖出价格 10209.38 卖出份额 0.011345224314714394 时间 2019/6/22
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.0766703380987 剩余资金:  2825.172005057365 交易位置:  10668.63 持有份额 0.011051528198159806 交易时间 2019/6/23 止损价位 -4675.932000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.0530894050426 卖出价格 10668.63 卖出份额 0.011051528198159806 时间 2019/6/23
# --------------------------------------------------
# 比特币建仓
# 总资本 2943.030179594757 剩余资金:  2828.4811281669827 交易位置:  10814.48 持有份额 0.010592192267013713 交易时间 2019/6/24 止损价位 -4530.082
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2943.0072697844716 卖出价格 10814.48 卖出份额 0.010592192267013713 时间 2019/6/24
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.9848719858905 剩余资金:  2830.9958790811365 交易位置:  11017.5 持有份额 0.010164646508259958 交易时间 2019/6/25 止损价位 -4525.493999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.9624741873095 卖出价格 11017.5 卖出份额 0.010164646508259958 时间 2019/6/25
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.9396639680826 剩余资金:  2828.888567832561 交易位置:  11766.4 持有份额 0.009692947387095583 交易时间 2019/6/26 止损价位 -3807.536
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.9168537488554 卖出价格 11766.4 卖出份额 0.009692947387095583 时间 2019/6/26
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.893432196966 剩余资金:  2825.785672750036 交易位置:  12932.55 持有份额 0.009055272119336842 交易时间 2019/6/27 止损价位 -2847.2160000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.8700106450765 卖出价格 12932.55 卖出份额 0.009055272119336842 时间 2019/6/27
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.8517476852994 剩余资金:  2851.536948800617 交易位置:  11132.85 持有份额 0.008202284130719661 交易时间 2019/6/28 止损价位 -4646.915999999999
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.7969588059686 卖出价格 11132.85 卖出份额 0.016404568261439323 时间 2019/6/28
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.768117317809 剩余资金:  2798.560676518892 交易位置:  8813.89 持有份额 0.01636138422409596 交易时间 2020/1/16 止损价位 -5477.934000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.739275829649 卖出价格 8813.89 卖出份额 0.01636138422409596 时间 2020/1/16
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.7119917628575 剩余资金:  2806.2916578036256 交易位置:  8910.85 持有份额 0.015309463626840493 交易时间 2020/1/19 止损价位 -5380.974
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.6847076960653 卖出价格 8910.85 卖出份额 0.015309463626840493 时间 2020/1/19
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.6583662742696 剩余资金:  2810.951257294966 交易位置:  8703.36 持有份额 0.015132903726756478 交易时间 2020/1/20 止损价位 -5588.464
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.6320248524735 卖出价格 8703.36 卖出份额 0.015132903726756478 时间 2020/1/20
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.601450508814 剩余资金:  2789.7297322128206 交易位置:  9279.81 持有份额 0.016473582788440026 交易时间 2020/1/30 止损价位 -6913.92
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.570876165155 卖出价格 9279.81 卖出份额 0.016473582788440026 时间 2020/1/30
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.542457152436 剩余资金:  2800.44739355811 交易位置:  9333.77 持有份额 0.015223758844960383 交易时间 2020/2/1 止损价位 -7000.423999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.514038139717 卖出价格 9333.77 卖出份额 0.015223758844960383 时间 2020/2/1
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.4838205824767 剩余资金:  2791.396034382301 交易位置:  9755.66 持有份额 0.015487192686109992 交易时间 2020/2/7 止损价位 -7008.41
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.4536030252366 卖出价格 9755.66 卖出份额 0.015487192686109992 时间 2020/2/7
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.423101540574 剩余资金:  2789.9156782269524 交易位置:  9807.54 持有份额 0.01555001797735431 交易时间 2020/2/8 止损价位 -6956.529999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.3926000559113 卖出价格 9807.54 卖出份额 0.01555001797735431 时间 2020/2/8
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.3617944192715 剩余资金:  2788.3336112198385 交易位置:  9907.12 持有份额 0.015547220907734331 交易时间 2020/2/9 止损价位 -6856.949999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.3309887826317 卖出价格 9907.12 卖出份额 0.015547220907734331 时间 2020/2/9
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.2996373833407 剩余资金:  2785.5426409284337 交易位置:  10162.41 持有份额 0.015425179308343872 交易时间 2020/2/10 止损价位 -6601.66
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.2682859840497 卖出价格 10162.41 卖出份额 0.015425179308343872 时间 2020/2/10
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.2386871156978 剩余资金:  2794.2443453559567 交易位置:  9854.79 持有份额 0.015017503342003316 交易时间 2020/2/11 止损价位 -6909.279999999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.209088247346 卖出价格 9854.79 卖出份额 0.015017503342003316 时间 2020/2/11
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.178701553005 剩余资金:  2790.245229849494 交易位置:  10354.3 持有份额 0.014673466260733308 交易时间 2020/2/13 止损价位 -6481.878000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.1483148586644 卖出价格 10354.3 卖出份额 0.014673466260733308 时间 2020/2/13
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.118072614339 剩余资金:  2790.90685098566 交易位置:  10242.43 持有份额 0.014763217481464698 交易时间 2020/2/14 止损价位 -6882.198
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2942.087830370013 卖出价格 10242.43 卖出份额 0.014763217481464698 时间 2020/2/14
# --------------------------------------------------
# 比特币建仓
# 总资本 2942.057952397551 剩余资金:  2792.6680900871575 交易位置:  9904.17 持有份额 0.015083531715468685 交易时间 2020/2/16 止损价位 -8366.837999999998
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.9683184801647 卖出价格 9904.17 卖出份额 0.03016706343093737 时间 2020/2/16
# --------------------------------------------------
# 黄金建仓
# 总资本 2941.9219692403253 剩余资金:  2478.4295708462137 交易位置:  1724.9 持有份额 0.2687068226529721 交易时间 2020/5/21 止损价位 -1672.5899999999997
# 黄金加仓
# 总资本 2941.8756200004855 剩余资金:  2014.8908232122626 交易位置:  1724.9 持有份额 0.5374136453059442 交易时间 2020/5/21
# --------------------------------------------------
# 黄金卖出
# M 当前总资本 2941.7829215208067 卖出价格 1724.9 卖出份额 0.5374136453059442 时间 2020/5/21
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.7625190713798 剩余资金:  2839.7502719371987 交易位置:  9525.57 持有份额 0.010709306333813229 交易时间 2020/6/3 止损价位 -8137.706000000002
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.7013117230995 卖出价格 9525.57 卖出份额 0.021418612667626458 时间 2020/6/3
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.6524850376054 剩余资金:  2697.5190575668944 交易位置:  10934.94 持有份额 0.022325996070459556 交易时间 2020/7/29 止损价位 -7368.8020000000015
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.6036583521113 卖出价格 10934.94 卖出份额 0.022325996070459556 时间 2020/7/29
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.563481070928 剩余资金:  2740.6770751542076 交易位置:  11114.93 持有份额 0.018073564648335195 交易时间 2020/7/31 止损价位 -7188.812000000002
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.5233037897447 卖出价格 11114.93 卖出份额 0.018073564648335195 时间 2020/7/31
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.48572958221 剩余资金:  2753.614691909131 交易位置:  11343.88 持有份额 0.016561444379972173 交易时间 2020/8/1 止损价位 -6959.862000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.448155374675 卖出价格 11343.88 卖出份额 0.016561444379972173 时间 2020/8/1
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.4120767661116 剩余资金:  2761.019033949278 交易位置:  11823.69 持有份额 0.015256915803512575 交易时间 2020/8/2 止损价位 -6480.0520000000015
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.375998157548 卖出价格 11823.69 卖出份额 0.015256915803512575 时间 2020/8/2
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.3450940058106 剩余资金:  2786.8243353175976 交易位置:  11077.77 持有份额 0.013948724218702215 交易时间 2020/8/3 止损价位 -7225.972000000002
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.2523815505974 卖出价格 11077.77 卖出份额 0.02789744843740443 时间 2020/8/3
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.2209442644094 剩余资金:  2784.0345133239975 交易位置:  11392.43 持有份额 0.01379744540369455 交易时间 2020/8/12 止损价位 -7821.424000000003
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.126632405845 卖出价格 11392.43 卖出份额 0.0275948908073891 时间 2020/8/12
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.0897384754217 剩余资金:  2756.6200863573613 交易位置:  12293.72 持有份额 0.015005193880945756 交易时间 2020/8/18 止损价位 -9906.640000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2941.052844544998 卖出价格 12293.72 卖出份额 0.015005193880945756 时间 2020/8/18
# --------------------------------------------------
# 比特币建仓
# 总资本 2941.0175454960827 剩余资金:  2764.5223009187816 交易位置:  11969.53 持有份额 0.0147453780204654 交易时间 2020/8/19 止损价位 -10252.898
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.982246447167 卖出价格 11969.53 卖出份额 0.0147453780204654 时间 2020/8/19
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.955731036243 剩余资金:  2808.3786764135966 交易位置:  23150.79 持有份额 0.005726675185712722 交易时间 2020/12/19 止损价位 -13199.961999999992
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.929215625318 卖出价格 23150.79 卖出份额 0.005726675185712722 时间 2020/12/19
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.9037716213847 剩余资金:  2813.683751953834 交易位置:  23869.92 持有份额 0.005329721241945955 交易时间 2020/12/20 止损价位 -12581.919999999998
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.878327617451 卖出价格 23869.92 卖出份额 0.005329721241945955 时间 2020/12/20
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.8550434423455 剩余资金:  2824.434167916966 交易位置:  23490.58 持有份额 0.004956066454101156 交易时间 2020/12/21 止损价位 -12961.259999999995
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.8317592672406 卖出价格 23490.58 卖出份额 0.004956066454101156 时间 2020/12/21
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.8071571138084 剩余资金:  2817.796389952207 交易位置:  26443.21 持有份额 0.004651884818885508 交易时间 2020/12/27 止损价位 -10008.629999999997
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.7825549603763 卖出价格 26443.21 卖出份额 0.004651884818885508 时间 2020/12/27
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.7589844519207 剩余资金:  2822.906442172057 交易位置:  26246.58 持有份额 0.004490205667933259 交易时间 2020/12/28 止损价位 -10205.259999999995
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.7354139434647 卖出价格 26246.58 卖出份额 0.004490205667933259 时间 2020/12/28
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.7123576184167 剩余资金:  2825.4307323788753 交易位置:  27376.37 持有份额 0.004210990180200712 交易时间 2020/12/30 止损价位 -9075.469999999998
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.6893012933688 卖出价格 27376.37 卖出份额 0.004210990180200712 时间 2020/12/30
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.665861151319 剩余资金:  2823.4651509037426 交易位置:  28856.59 持有份额 0.004061488562840464 交易时间 2020/12/31 止损价位 -8595.473999999998
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.6424210092696 卖出价格 28856.59 卖出份额 0.004061488562840464 时间 2020/12/31
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.620093213931 剩余资金:  2828.981116519817 交易位置:  28982.56 持有份额 0.0038519363608360982 交易时间 2021/1/1 止损价位 -9274.192
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.597765418592 卖出价格 28982.56 卖出份额 0.0038519363608360982 时间 2021/1/1
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.575835847985 剩余资金:  2830.9279828117856 交易位置:  29393.75 持有份额 0.0037303118192200556 交易时间 2021/1/2 止损价位 -9137.008000000002
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.553906277378 卖出价格 29393.75 卖出份额 0.0037303118192200556 时间 2021/1/2
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.5300936176486 剩余资金:  2821.466794970672 交易位置:  32195.46 持有份额 0.0036981393850864875 交易时间 2021/1/3 止损价位 -6651.408000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.506280957919 卖出价格 32195.46 卖出份额 0.0036981393850864875 时间 2021/1/3
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.483254239687 剩余资金:  2825.349663080157 交易位置:  33000.78 持有份额 0.0034888142389219315 交易时间 2021/1/4 止损价位 -9370.233999999997
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.460227521455 卖出价格 33000.78 卖出份额 0.0034888142389219315 时间 2021/1/4
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.439020645102 剩余资金:  2834.404638879553 交易位置:  32035.03 持有份额 0.0033099510681135237 交易时间 2021/1/5 止损价位 -13182.730000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.417813768749 卖出价格 32035.03 卖出份额 0.0033099510681135237 时间 2021/1/5
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.395153378008 剩余资金:  2827.0931996740414 交易位置:  36860.41 持有份额 0.0030738115420844937 交易时间 2021/1/7 止损价位 -9360.108
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.3724929872674 卖出价格 36860.41 卖出份额 0.0030738115420844937 时间 2021/1/7
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.3498292838617 剩余资金:  2827.031312255366 交易位置:  39486.04 持有份额 0.0028698374673301152 交易时间 2021/1/8 止损价位 -6919.121999999996
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.327165580456 卖出价格 39486.04 卖出份额 0.0028698374673301152 时间 2021/1/8
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.305843825894 剩余资金:  2833.697071016047 交易位置:  40670.25 持有份额 0.0026212962253698182 交易时间 2021/1/9 止损价位 -5734.911999999997
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.284522071332 卖出价格 40670.25 卖出份额 0.0026212962253698182 时间 2021/1/9
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.264679126475 剩余资金:  2841.049954842761 交易位置:  40240.72 持有份额 0.0024655305442773915 交易时间 2021/1/10 止损价位 -6164.4419999999955
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.2448361816187 卖出价格 40240.72 卖出份额 0.0024655305442773915 时间 2021/1/10
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.226594838255 剩余资金:  2849.019878018792 交易位置:  46589.58 持有份额 0.0019576634264456324 交易时间 2021/2/10 止损价位 -14930.437999999995
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.208353494891 卖出价格 46589.58 卖出份额 0.0019576634264456324 时间 2021/2/10
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.1915202832533 剩余资金:  2856.0254620951528 交易位置:  44878.17 持有份额 0.001875434274349882 交易时间 2021/2/11 止损价位 -18985.196000000004
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.1746870716156 卖出价格 44878.17 卖出份额 0.001875434274349882 时间 2021/2/11
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.1581877997746 剩余资金:  2857.6618285968043 交易位置:  47471.4 持有份额 0.0017378118025373284 交易时间 2021/2/13 止损价位 -16650.30199999999
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.141688527934 卖出价格 47471.4 卖出份额 0.0017378118025373284 时间 2021/2/13
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.1256169370527 剩余资金:  2859.7676625289696 交易位置:  47951.85 持有份额 0.0016758050921514595 交易时间 2021/2/16 止损价位 -17777.612
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.1095453461708 卖出价格 47951.85 卖出份额 0.0016758050921514595 时间 2021/2/16
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.091517819525 剩余资金:  2849.953884591897 交易位置:  52118.23 持有份额 0.0017294837761686868 交易时间 2021/2/18 止损价位 -14850.282
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.0734902928793 卖出价格 52118.23 卖出份额 0.0017294837761686868 时间 2021/2/18
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.055507170302 剩余资金:  2850.1398942833052 交易位置:  51608.15 持有份额 0.0017422754523655005 交易时间 2021/2/19 止损价位 -15360.362000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2940.0375240477247 卖出价格 51608.15 卖出份额 0.0017422754523655005 时间 2021/2/19
# --------------------------------------------------
# 比特币建仓
# 总资本 2940.0183812586665 剩余资金:  2844.3044359683245 交易位置:  56001.2 持有份额 0.0017091409700210399 交易时间 2021/2/21 止损价位 -14656.768000000011
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.999238469609 卖出价格 56001.2 卖出份额 0.0017091409700210399 时间 2021/2/21
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.9799498801026 剩余资金:  2843.5370023502865 交易位置:  57487.86 持有份额 0.0016776228499341653 交易时间 2021/2/22 止损价位 -16221.834000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.960661290597 卖出价格 57487.86 卖出份额 0.0016776228499341653 时间 2021/2/22
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.943030298403 剩余资金:  2851.788069328905 交易位置:  54123.4 持有份额 0.0016287772196406358 交易时间 2021/2/23 止损价位 -21094.268000000004
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.890137321821 卖出价格 54123.4 卖出份额 0.0032575544392812717 时间 2021/2/23
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.8727795532586 剩余资金:  2853.083936740908 交易位置:  57253.28 持有份额 0.0015158754714550936 交易时间 2021/3/13 止损价位 -34850.07000000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.855421784696 卖出价格 57253.28 卖出份额 0.0015158754714550936 时间 2021/3/13
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.8382318755853 剩余资金:  2853.8886863240177 交易位置:  59133.47 持有份额 0.0014534838823354631 交易时间 2021/3/15 止损价位 -32969.880000000005
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.821041966475 卖出价格 59133.47 卖出份额 0.0014534838823354631 时间 2021/3/15
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.7956631248676 剩余资金:  2812.901455087665 交易位置:  62969.12 持有份额 0.002015181537191604 交易时间 2021/4/15 止损价位 -48456.452
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.77028428326 卖出价格 62969.12 卖出份额 0.002015181537191604 时间 2021/4/15
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.751054881351 剩余资金:  2843.6040453366854 交易位置:  41659.06 持有份额 0.0023079495683451783 交易时间 2021/8/1 止损价位 -19767.679999999993
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.7318254794423 卖出价格 41659.06 卖出份额 0.0023079495683451783 时间 2021/8/1
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.711428917281 剩余资金:  2837.728618111472 交易位置:  44634.13 持有份额 0.002284861625079487 交易时间 2021/8/8 止损价位 -16792.609999999993
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.6910323551197 卖出价格 44634.13 卖出份额 0.002284861625079487 时间 2021/8/8
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.671482956791 剩余资金:  2841.924491313064 交易位置:  43816.14 持有份额 0.002230844424993318 交易时间 2021/8/9 止损价位 -19954.415999999997
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.651933558462 卖出价格 43816.14 卖出份额 0.002230844424993318 时间 2021/8/9
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.632786035571 剩余资金:  2843.8951715784883 交易位置:  45608.37 持有份额 0.002099123789275574 交易时间 2021/8/11 止损价位 -21298.141999999985
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.6136385126792 卖出价格 45608.37 卖出份额 0.002099123789275574 时间 2021/8/11
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.59390952033 剩余资金:  2840.9489477737334 交易位置:  47112.19 持有份额 0.002093830954294343 交易时间 2021/8/15 止损价位 -28999.838000000003
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.5741805279804 卖出价格 47112.19 卖出份额 0.002093830954294343 时间 2021/8/15
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.552139340599 剩余资金:  2829.3462024332025 交易位置:  48932.02 持有份额 0.002252225371186317 交易时间 2021/8/22 止损价位 -29244.672000000013
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.5300981532173 卖出价格 48932.02 卖出份额 0.002252225371186317 时间 2021/8/22
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.5079090339773 剩余资金:  2828.562312834187 交易位置:  49523.5 持有份额 0.0022402616172077935 交易时间 2021/8/24 止损价位 -32014.127999999997
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.4857199147373 卖出价格 49523.5 卖出份额 0.0022402616172077935 时间 2021/8/24
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.4644259162237 剩余资金:  2832.9944333466788 交易位置:  47744.58 持有份额 0.002229991185796268 交易时间 2021/8/25 止损价位 -37518.529999999984
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.4431319177097 卖出价格 47744.58 卖出份额 0.002229991185796268 时间 2021/8/25
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.4159335895224 剩余资金:  2803.424292654379 交易位置:  49947.38 持有份额 0.0027226981862741094 交易时间 2021/9/5 止损价位 -39582.481999999996
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.3887352613356 卖出价格 49947.38 卖出份额 0.0027226981862741094 时间 2021/9/5
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.360184348552 剩余资金:  2796.6056204314004 交易位置:  52677.4 持有份额 0.002709977408094398 交易时间 2021/9/7 止损价位 -40400.54200000001
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.3316334357687 卖出价格 52677.4 卖出份额 0.002709977408094398 时间 2021/9/7
# --------------------------------------------------
# 比特币建仓
# 总资本 2939.3068774249627 剩余资金:  2815.526823396409 交易位置:  46809.17 持有份额 0.0026443548139937953 交易时间 2021/9/8 止损价位 -47070.8
# 比特币加仓
# --------------------------------------------------
# 比特币卖出
# M 当前总资本 2939.2326093925453 卖出价格 46809.17 卖出份额 0.005288709627987591 时间 2021/9/8
# --------------------------------------------------
