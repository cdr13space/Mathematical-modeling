# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %%
path = r"C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\第三问"
dirPath =  glob.glob(os.path.join(path,"*.xls"))
for (a,b) in enumerate(dirPath):
    print("{}:   {}".format(a,b[87:-4]))
# Out:
# 0:   天然气消费量(亿立方米)
# 1:   柴油消费量(万吨)
# 2:   森林面积(万公顷)
# 3:   汽油消费量(万吨)
# 4:   焦炭消费量(万吨)
# 5:   煤油消费量(万吨)
# 6:   煤炭消耗量(万吨)
# 7:   燃料油消费量(万吨)
# 8:   电力消费量(亿千瓦小时)
# 9:   碳排放量

# %%
coefficient = np.array([2.1622,3.0959,2.9251,2.8604,3.0179,1.9003,3.1705])

# %%
data_天然气 = pd.read_excel(dirPath[0]).iloc[:,1:]*coefficient[0]
data_柴油 =  pd.read_excel(dirPath[1]).iloc[:,1:]*coefficient[1]
data_汽油 =  pd.read_excel(dirPath[3]).iloc[:,1:]*coefficient[2]
data_焦炭 =  pd.read_excel(dirPath[4]).iloc[:,1:]*coefficient[3]
data_煤油 =  pd.read_excel(dirPath[5]).iloc[:,1:]*coefficient[4]
data_煤炭 =  pd.read_excel(dirPath[6]).iloc[:,1:]*coefficient[5]
data_燃料油 =  pd.read_excel(dirPath[7]).iloc[:,1:]*coefficient[6]

# %%
碳吸收系数 = 0.5
# 天然气一立方约等于0.71公斤
# 天然气转换为吨
data_天然气 = data_天然气*10000*0.71/1000
# 碳吸收量
data_森林面积 = pd.read_excel(dirPath[2]).iloc[:,1:]*coefficient[2]
data_森林吸收量 = data_森林面积*碳吸收系数

# %%
总排放量 = data_天然气+data_柴油+data_汽油+data_焦炭+data_煤油+data_煤炭+data_燃料油

# %%
data_森林面积
# Out:
#            北京市        天津市          河北省         山西省       内蒙古自治区          辽宁省  \
# 0   152.251455  27.261932  1223.657083  646.768861  6921.956640  1497.592698
# 1   152.251455  27.261932  1223.657083  646.768861  6921.956640  1497.592698
# 2   152.251455  27.261932  1223.657083  646.768861  6921.956640  1497.592698
# 3   152.251455  27.261932  1223.657083  646.768861  6921.956640  1497.592698
# 4   152.251455  27.261932  1223.657083  646.768861  6921.956640  1497.592698
# 5   172.025131  32.644116  1285.084183  826.077491  7277.356290  1630.187481
# 6   172.025131  32.644116  1285.084183  826.077491  7277.356290  1630.187481
# 7   172.025131  32.644116  1285.084183  826.077491  7277.356290  1630.187481
# 8   172.025131  32.644116  1285.084183  826.077491  7277.356290  1630.187481
# 9   172.025131  32.644116  1285.084183  826.077491  7277.356290  1630.187481
# 10  210.080682  39.898364  1470.418519  939.220359  7648.697735  1672.659933
# ...

# %%
总排放量 = data_天然气+data_柴油+data_汽油+data_焦炭+data_煤油+data_煤炭+data_燃料油
总排放量
# Out:
#              北京市           天津市           河北省            山西省         内蒙古自治区  \
# 0    9056.913521   9190.371244  43206.755438   51347.059019   24749.589764
# 1    9365.054387   9809.512295  54253.392022   56068.399810   30702.234027
# 2    9649.171428  10486.561174  58686.401294   62103.416873   36061.596804
# 3    9928.763839  11151.153865  64050.450169   64117.263912   41619.296049
# 4    9561.461301  11545.421536  66345.312378   63003.335685   49636.862970
# 5    9708.959446  12423.430817  70946.172827   62365.547412   54015.042536
# 6   10003.440929  13538.159051  76563.742679   66822.577093   59766.412958
# 7    9111.029188  14745.308412  86615.683651   73661.733633   74870.001738
# 8    9289.847876  15482.501800  87893.485336   76893.830175   77932.318294
# 9    8661.727202  15415.132585  88450.176913   78743.619840   75051.668533
# 10   8494.010485  15109.009968  83941.223522   80631.849616   76935.282939
# ...

# %%
t = (data_森林吸收量/总排放量).T
t.to_csv(r'C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\吸收比.csv')
t
# Out:
#                 0         1         2         3         4         5   \
# 北京市       0.008405  0.008129  0.007889  0.007667  0.007962  0.008859
# 天津市       0.001483  0.001390  0.001300  0.001222  0.001181  0.001314
# 河北省       0.014160  0.011277  0.010425  0.009552  0.009222  0.009057
# 山西省       0.006298  0.005768  0.005207  0.005044  0.005133  0.006623
# 内蒙古自治区    0.139840  0.112727  0.095974  0.083158  0.069726  0.067364
# 辽宁省       0.027097  0.022475  0.020447  0.018724  0.018138  0.018697
# 吉林省       0.086641  0.069767  0.062851  0.059275  0.056279  0.056368
# 黑龙江省      0.164840  0.143984  0.135557  0.124452  0.113518  0.113960
# 上海市       0.000548  0.000512  0.000504  0.000478  0.000468  0.000536
# 江苏省       0.005024  0.003896  0.003526  0.003269  0.003134  0.004583
# 浙江省       0.042562  0.036295  0.031279  0.027710  0.027153  0.027195
# 安徽省       0.030367  0.028603  0.026590  0.023738  0.020588  0.019741
# 福建省       0.115178  0.090575  0.082659  0.072746  0.068824  0.064257
# ...

# %%
from sklearn.cluster import

# %%
kmeans = KMeans(n_clusters=3,n_init=50).fit(t)
print('每项所属分类：{}'.format(kmeans.labels_))
# Out:
# 每项所属分类：[0 0 0 0 2 0 2 1 0 0 0 0 2 1 0 0 2 2 2 1 1 2 1 2 1 2 2 1 0 2]

# %%
kmeans.cluster_centers_
# Out:
# array([[0.01435349, 0.01231973, 0.01112884, 0.01006747, 0.00957866,
#         0.00996982, 0.00924566, 0.00850839, 0.00844008, 0.00845162,
#         0.00902996, 0.00911081, 0.00917602, 0.00902875, 0.00881779,
#         0.00887868, 0.00896675],
#        [0.17578619, 0.16614737, 0.14683601, 0.13229398, 0.12044432,
#         0.12120006, 0.1117908 , 0.10024356, 0.09337849, 0.09152759,
#         0.09938093, 0.10483728, 0.10159134, 0.10145021, 0.10153259,
#         0.09873542, 0.09624982],
#        [0.08332189, 0.0695504 , 0.06172984, 0.05562818, 0.0515489 ,
#         0.05158131, 0.0467025 , 0.04032168, 0.03883837, 0.03953702,
#         0.04096909, 0.04149123, 0.04149678, 0.04025734, 0.040104  ,
#         0.03879171, 0.03763601]])

# %%
index_0 = np.where(kmeans.labels_ == 0)[0].tolist()
label_0 = t.index[index_0].to_list()
print('第0类：{}'.format(label_0))
# Out:
# 第0类：['北京市', '天津市', '河北省', '山西省', '辽宁省', '上海市', '江苏省', '浙江省', '安徽省', '山东省', '河南省', '宁夏回族自治区']

# %%
index_1 = np.where(kmeans.labels_ == 1)[0].tolist()
label_1 = t.index[index_1].to_list()
print('第1类：{}'.format(label_1))
# Out:
# 第1类：['黑龙江省', '江西省', '广西壮族自治区', '海南省', '四川省', '云南省', '青海省']

# %%
index_2 = np.where(kmeans.labels_ == 2)[0].tolist()
label_2 = t.index[index_2].to_list()
print('第2类：{}'.format(label_2))
# Out:
# 第2类：['内蒙古自治区', '吉林省', '福建省', '湖北省', '湖南省', '广东省', '重庆市', '贵州省', '陕西省', '甘肃省', '新疆维吾尔自治区']

# %%
data = t.T
data[label_0].to_csv(r'C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\建立生态.csv')
data_森林面积[label_0].to_csv(r'C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\建立生态-面积.csv')
总排放量[label_0].to_csv(r'C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\建立生态-总排放量.csv')

# %%
碳排放预测 = pd.read_csv(r"C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\碳排放预测.csv").iloc[-6:,:]
碳排放预测
# Out:
#     Year        预测江苏省         预测山东省        预测河南省
# 15  2020  70608.79084  106935.47870  45336.41247
# 16  2021  69170.28297  105473.41390  41542.90018
# 17  2022  63389.32175   97585.35727  37258.54928
# 18  2023  59841.85679   90560.88428  32918.16684
# 19  2024  57052.84019   84743.20082  28612.19350
# 20  2025  54240.62252   79007.23133  24577.51405

# %%
森林预测 = pd.read_csv(r"C:\Git Code\Mathematical-modeling\Simulation practice\2021 APMCM C\Preprocess Data\森林预测.csv").iloc[-6:,:]
碳吸收系数 = 0.5
森林预测.iloc[:,1:] = 森林预测.iloc[:,1:]*碳吸收系数
森林预测
# Out:
#     Year      预测_江苏省      预测_山东省      预测_河南省      生态_江苏省      生态_山东省  \
# 15  2020  228.953124  393.030281  603.359626  228.953124  393.030281
# 16  2021  227.470442  394.113237  607.608270  236.188043  405.450037
# 17  2022  225.288592  398.040124  622.148370  243.651585  418.262259
# 18  2023  221.895103  401.795709  635.059751  251.350975  431.479346
# 19  2024  217.457534  405.519183  647.271238  259.293666  445.114093
# 20  2025  212.070264  409.294473  659.270645  267.487346  459.179699
#
#         生态_河南省
# 15  603.359626
# 16  622.425790
# 17  642.094445
# 18  662.384629
# 19  683.315984
# 20  704.908769

# %%
碳排放预测.iloc[:,1].tolist()
# Out:
# [70608.79084, 69170.28297, 63389.32175, 59841.85679, 57052.84019, 54240.62252]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei'] # 解决中文乱码

labels = ['第一项', '第二项','第三项']
a = [4.0, 3.8]
b = [26.9, 48.1]
c = [55.6, 63.0]
d = [59.3, 81.5]
e = [89, 90]    


x = np.arange(len(labels))  # 标签位置
width = 0.1  # 柱状图的宽度，可以根据自己的需求和审美来改

fig, ax = plt.subplots()
rects2 = ax.bar(x - width+0.01, 碳排放预测.iloc[:,1].tolist(), width, label='b')
rects3 = ax.bar(x + 0.02, 森林预测.iloc[:,1].tolist(), width, label='c')
rects4 = ax.bar(x + width+ 0.03, 森林预测.iloc[:,4].tolist(), width, label='d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17680/4256703128.py in <module>
#      17
#      18 fig, ax = plt.subplots()
# ---> 19 rects2 = ax.bar(x - width+0.01, 碳排放预测.iloc[:,1].tolist(), width, label='b')
#      20 rects3 = ax.bar(x + 0.02, 森林预测.iloc[:,1].tolist(), width, label='c')
#      21 rects4 = ax.bar(x + width+ 0.03, 森林预测.iloc[:,4].tolist(), width, label='d')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# 防止乱码
mpl.rcParams["font.sans-serif"] = ["SimHei"]
mpl.rcParams["axes.unicode_minus"] = False

# 生成数据
x = np.arange(5)
y1 = 碳排放预测.iloc[:,1].values
y2 = 森林预测.iloc[:,1].values
y3 = 森林预测.iloc[:,4].values

bar_width = 0.35
tick_label = ["A","B","C","D","E"]

# 生成多数据并列柱状图
plt.bar(x,y2,bar_width,color="c",align="center",label="班级A",alpha=0.5)
plt.bar(x+bar_width,y3,bar_width,color="b",align="center",label="班级B",alpha=0.5)
# 生成多数据平行柱状图
# plt.barh(x,y,bar_width,color="c",align="center",label="班级A",alpha=0.5)
# plt.barh(x+bar_width,y1,bar_width,color="b",align="center",label="班级B",alpha=0.5)


# 设置x,y轴标签
plt.xlabel("测试难度")
plt.ylabel("试卷份数")

# 设置x轴标签位置
plt.xticks(x+bar_width/2,tick_label)

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17680/615798986.py in <module>
#      17
#      18 # 生成多数据并列柱状图
# ---> 19 plt.bar(x,y2,bar_width,color="c",align="center",label="班级A",alpha=0.5)
#      20 plt.bar(x+bar_width,y3,bar_width,color="b",align="center",label="班级B",alpha=0.5)
#      21 # 生成多数据平行柱状图
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
森林预测.iloc[:,1].values
# Out:
# array([228.95312415, 227.47044235, 225.28859165, 221.8951028 ,
#        217.457534  , 212.0702637 ])
